# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, silhouette_score
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans

import os
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from PIL import Image

import requests
from PIL import Image
import numpy as np
from io import BytesIO
import os

# %%
bp_track = pd.read_csv('data/bp_track.csv')
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\1573399701.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   bp_track = pd.read_csv('data/bp_track.csv')

# %%
bp_genre = pd.read_csv('data/bp_genre.csv')

# %%
bp_genre.head()
# Out:
#    genre_id                            genre_name  song_count  \
# 0         8                 Hard Dance / Hardcore      178646
# 1        50                      Nu Disco / Disco      157934
# 2        12                            Deep House      897280
# 3        85                           Bass / Club       20716
# 4        94  Electro (Classic / Detroit / Modern)       19615
#
#                                   genre_url           updated_on
# 0              /genre/hard-dance-hardcore/8  2023-09-19 15:01:03
# 1                  /genre/nu-disco-disco/50  2023-09-19 15:01:03
# 2                      /genre/deep-house/12  2023-09-19 15:01:03
# 3                       /genre/bass-club/85  2023-09-19 15:01:03
# 4  /genre/electro-classic-detroit-modern/94  2023-09-19 15:01:03

# %%
bp_track.drop(columns=['track_id', 'title', 'mix', 'is_remixed', 'release_date', 'track_url', 'duration', 'duration_ms', 'isrc', 'updated_on', 'is_matched_spot', 'subgenre_id', 'label_id', 'release_id'], inplace=True, axis=1)

# %%
bp_track.isnull().sum()
# Out:
# genre_id       0
# bpm            0
# key_id      6254
# dtype: int64

# %%
bp_track = bp_track.dropna()

# %%
bp_key = pd.read_csv('data/bp_key.csv')

# %%
bp_track_updated = pd.merge(bp_track, bp_key[['key_id', 'scale_numeric_value']], on='key_id', how='left')

# Drop the old 'key_id' and rename 'scale_numeric_value' to 'key_id'
bp_track = bp_track_updated.drop(columns=['key_id']).rename(columns={'scale_numeric_value': 'key_id'})

# %%
# Define your desired sample size for each class
sample_size = 5000  # Adjust this to your desired sample size

# Get the minimum count of samples available across all genres
min_count = bp_track['genre_id'].value_counts().min()

# Ensure the sample size does not exceed the minimum class size
sample_size_per_class = min(sample_size, min_count)

# Sample from each genre
bp_sample = bp_track.groupby('genre_id').apply(lambda x: x.sample(sample_size_per_class)).reset_index(drop=True)

# Display the balanced sample
bp_sample.head()
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\2565442244.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   bp_sample = bp_track.groupby('genre_id').apply(lambda x: x.sample(sample_size_per_class)).reset_index(drop=True)
#    genre_id  bpm  key_id
# 0         1   86       5
# 1         1  164       1
# 2         1   86       5
# 3         1   86      17
# 4         1   87      16

# %%
features = bp_sample.drop(columns='genre_id')

# %%
X = features
y = bp_sample['genre_id']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
def train_and_evaluate_model(models):
    metrics = {
        'Accuracy': accuracy_score,
        'Precision': precision_score,
        'Recall': recall_score,
        'F1 Score': f1_score,
        'ROC AUC': roc_auc_score
    }

    results = {}

    for model in models:
        model_scores = {}
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Compute each metric
        for metric_name, metric_function in metrics.items():
            if metric_name == 'ROC AUC':
                # For binary or multiclass classification, use the predict_proba method
                if hasattr(model, "predict_proba"):
                    y_pred_prob = model.predict_proba(X_test)
                    if y_pred_prob.shape[1] == 2:
                        # Binary classification case
                        score = metric_function(y_test, y_pred_prob[:, 1])
                    else:
                        # Multiclass case
                        score = metric_function(y_test, y_pred_prob, multi_class='ovr')
                else:
                    score = "N/A"  # In case model does not support predict_proba
            else:
                # For multiclass classification, use 'weighted' average
                if metric_name in ['Precision', 'Recall', 'F1 Score']:
                    score = metric_function(y_test, y_pred, average='weighted')
                else:
                    score = metric_function(y_test, y_pred)

            model_scores[metric_name] = score

        results[str(model)] = model_scores

    return results

# %%
models = [
    LogisticRegression(),               # Linear model
    RandomForestClassifier(),           # Ensemble of decision trees
    GradientBoostingClassifier(),       # Boosting method
    AdaBoostClassifier(),               # Boosting method
    BaggingClassifier(),                # Bagging method
    KNeighborsClassifier(),             # k-NN classifier
    DecisionTreeClassifier(),           # Simple decision tree
    ExtraTreesClassifier()
    ]
model_metrics = train_and_evaluate_model(models=models)
# Out:
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Prepare data for plotting
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']
metric_results = {metric: [] for metric in metrics}

# Collect data for each metric
for model, scores in model_metrics.items():
    for metric in metrics:
        metric_results[metric].append(scores.get(metric, 0))

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(20, 20), sharey=True)

# Plot each metric
for i, metric in enumerate(metrics):
    ax = axes[i]
    sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)

    # Add labels to the bars
    for j, value in enumerate(metric_results[metric]):
        ax.text(j, value + 0.01, f'{value:.2f}', ha='center', va='bottom')

    # Set labels and title
    ax.set_xlabel('Model', fontsize=12)
    ax.set_ylim([0,1])
    ax.set_title(metric, fontsize=14, weight='bold')
    ax.set_xticklabels(ax.get_xticklabels())

# Set common ylabel
axes[0].set_ylabel('Score', fontsize=12)

# Adjust layout
plt.tight_layout()

# Show plot
# plt.savefig('savefig/ClassificationModels.png')
plt.show()
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())

# %% [markdown]
# _________

# %% [markdown]
# # Manual Grouping

# %%
genre_mapping = {
    # House Group
    'House': 'House',
    'Tech House': 'House',
    'Deep House': 'House',
    'Progressive House': 'House',
    'Funky House': 'House',
    'Jackin House': 'House',
    'Afro House': 'House',
    'Bass House': 'House',

    # Techno Group
    'Techno (Peak Time / Driving)': 'Techno',
    'Techno (Raw / Deep / Hypnotic)': 'Techno',
    'Minimal / Deep Tech': 'Techno',
    'Melodic House & Techno': 'Techno',
    'Hard Techno': 'Techno',

    # Trance Group
    'Trance (Main Floor)': 'Trance',
    'Psy-Trance': 'Trance',
    'Trance (Raw / Deep / Hypnotic)': 'Trance',

    # Bass Music Group
    'Drum & Bass': 'Bass Music',
    'Dubstep': 'Bass Music',
    '140 / Deep Dubstep / Grime': 'Bass Music',
    'Trap / Wave': 'Bass Music',
    'Breaks / Breakbeat / UK Bass': 'Bass Music',
    'Bass / Club': 'Bass Music',
    'UK Garage / Bassline': 'Bass Music',

    # Hard Dance & Hardcore Group
    'Hard Dance / Hardcore': 'Hard Dance & Hardcore',

    # Dance/Pop Group
    'Mainstage': 'Dance/Pop',
    'Dance / Electro Pop': 'Dance/Pop',
    'Nu Disco / Disco': 'Dance/Pop',

    # Downtempo & World Group
    'Organic House / Downtempo': 'Downtempo & World',
    'Amapiano': 'Downtempo & World',

    # Experimental & Indie Group
    'Electronica': 'Experimental & Indie',
    'Indie Dance': 'Experimental & Indie',
    'Electro (Classic / Detroit / Modern)': 'Experimental & Indie'
}

# %%
# Assuming your DataFrame is df and it has a column 'genre_name'
bp_genre['broad_genre'] = bp_genre['genre_name'].map(genre_mapping)

# Check the result
print(bp_genre[['genre_name', 'broad_genre']])
# Out:
#                               genre_name            broad_genre
# 0                  Hard Dance / Hardcore  Hard Dance & Hardcore
# 1                       Nu Disco / Disco              Dance/Pop
# 2                             Deep House                  House
# 3                            Bass / Club             Bass Music
# 4   Electro (Classic / Detroit / Modern)   Experimental & Indie
# 5                            Hard Techno                 Techno
# 6                                Dubstep             Bass Music
# 7             140 / Deep Dubstep / Grime             Bass Music
# 8                            Funky House                  House
# 9                      Progressive House                  House
# 10             Organic House / Downtempo      Downtempo & World
# 11                           Indie Dance   Experimental & Indie
# 12                            Afro House                  House
# 13                   Minimal / Deep Tech                 Techno
# 14                             Mainstage              Dance/Pop
# 15                          Jackin House                  House
# 16                           Drum & Bass             Bass Music
# 17                           Electronica   Experimental & Indie
# 18                              Amapiano      Downtempo & World
# 19                Melodic House & Techno                 Techno
# 20                                 House                  House
# 21                            Bass House                  House
# 22                   Dance / Electro Pop              Dance/Pop
# 23          Breaks / Breakbeat / UK Bass             Bass Music
# 24                            Psy-Trance                 Trance
# 25        Techno (Raw / Deep / Hypnotic)                 Techno
# 26                            Tech House                  House
# 27        Trance (Raw / Deep / Hypnotic)                 Trance
# 28                   Trance (Main Floor)                 Trance
# 29          Techno (Peak Time / Driving)                 Techno
# 30                  UK Garage / Bassline             Bass Music
# 31                           Trap / Wave             Bass Music

# %%
# Assuming bp_media contains the genre_id and you want to replace it with genre_name

# Merge bp_media with bp_genre on 'genre_id'
bp_track = pd.merge(bp_track, bp_genre[['genre_id', 'broad_genre']], on='genre_id', how='left')

# Optionally, drop 'genre_id' if you no longer need it
bp_track.drop('genre_id', axis=1, inplace=True)

# %%
bp_track.isnull().sum()
# Out:
# bpm            0
# key_id         0
# broad_genre    0
# dtype: int64

# %%
# Define your desired sample size for each class
sample_size = 5000  # Adjust this to your desired sample size

# Get the minimum count of samples available across all genres
min_count = bp_track['broad_genre'].value_counts().min()

# Ensure the sample size does not exceed the minimum class size
sample_size_per_class = min(sample_size, min_count)

# Sample from each genre
bp_sample = bp_track.groupby('broad_genre').apply(lambda x: x.sample(sample_size_per_class)).reset_index(drop=True)
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\990210175.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   bp_sample = bp_track.groupby('broad_genre').apply(lambda x: x.sample(sample_size_per_class)).reset_index(drop=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Fit and transform the broad_genre column
bp_sample['broad_genre_encoded'] = le.fit_transform(bp_sample['broad_genre'])

# Check the result
bp_sample.head()
# Out:
#    bpm  key_id broad_genre  broad_genre_encoded
# 0   88      13  Bass Music                    0
# 1  140      11  Bass Music                    0
# 2   94       6  Bass Music                    0
# 3  130       9  Bass Music                    0
# 4  129      11  Bass Music                    0

# %%
features = bp_sample.drop(columns=['broad_genre', 'broad_genre_encoded'])

# %%
X = features
y = bp_sample['broad_genre_encoded']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
model_metrics = train_and_evaluate_model(models=models)
# Out:
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
# Prepare data for plotting
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']
metric_results = {metric: [] for metric in metrics}

# Collect data for each metric
for model, scores in model_metrics.items():
    for metric in metrics:
        metric_results[metric].append(scores.get(metric, 0))

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(20, 20), sharey=True)

# Plot each metric
for i, metric in enumerate(metrics):
    ax = axes[i]
    sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)

    # Add labels to the bars
    for j, value in enumerate(metric_results[metric]):
        ax.text(j, value + 0.01, f'{value:.2f}', ha='center', va='bottom')

    # Set labels and title
    ax.set_xlabel('Model', fontsize=12)
    ax.set_ylim([0,1])
    ax.set_title(metric, fontsize=14, weight='bold')
    ax.set_xticklabels(ax.get_xticklabels())

# Set common ylabel
axes[0].set_ylabel('Score', fontsize=12)

# Adjust layout
plt.tight_layout()

# Show plot
# plt.savefig('savefig/ClassificationModels.png')
plt.show()
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(model_metrics.keys()), y=metric_results[metric], palette="Blues_r", ax=ax)
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\391156369.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels())

# %% [markdown]
# _________

# %%
bp_track.head()
# Out:
#    bpm  key_id broad_genre
# 0  130      20      Trance
# 1  124       4      Trance
# 2  124       6      Trance
# 3   93      10      Trance
# 4  125       2      Trance

# %%
sampled_data = bp_track.sample(n=5000, random_state=42)

# %%
bp_clustering = sampled_data.drop(columns='broad_genre', axis=1)

# %%
scaler = StandardScaler()

bp_clustering = scaler.fit_transform(bp_clustering)

# %% [markdown]
# _________

# %% [markdown]
# # KMeans Clustering

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Step 1: Apply KMeans for a range of cluster numbers
inertia = []
cluster_range = range(2, 15)  # Try different numbers of clusters, from 2 to 15

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(bp_clustering)
    inertia.append(kmeans.inertia_)

# Step 2: Plot the Elbow Curve
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia (Sum of squared distances)')
plt.show()

# %%
from sklearn.metrics import silhouette_score

# Step 1: Apply KMeans and compute Silhouette Scores for a range of cluster numbers
silhouette_scores = []
cluster_range = range(2, 15)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    clusters = kmeans.fit_predict(bp_clustering)
    silhouette_avg = silhouette_score(bp_clustering, clusters)
    silhouette_scores.append(silhouette_avg)

# Step 2: Plot Silhouette Scores
plt.plot(cluster_range, silhouette_scores, marker='o')
plt.title('Silhouette Score for Optimal Number of Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
n_clusters = 8
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
clusters = kmeans.fit_predict(bp_clustering)

# %%
sil_score = silhouette_score(bp_clustering, clusters)
print(f'Silhouette Score: {sil_score}')
# Out:
# Silhouette Score: 0.4477353470392841

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reduce the dimensions of the data to 2D for visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(bp_clustering)

# Plot the clusters in 2D space
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=clusters, cmap='viridis')
plt.colorbar()
plt.title('KMeans Clusters Visualized with PCA')
plt.show()

# %% [markdown]
# _________

# %% [markdown]
# # DBSCAN Clustering

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt

# Find the k-nearest neighbors for each point (using k=4, as DBSCAN requires)
neighbors = NearestNeighbors(n_neighbors=4)
neighbors_fit = neighbors.fit(bp_clustering)
distances, indices = neighbors_fit.kneighbors(bp_clustering)

# Sort the distances to plot them
distances = np.sort(distances[:, 3], axis=0)  # Use the 4th nearest neighbor distance (for 4 neighbors)
plt.plot(distances)
plt.title('k-NN Distance Plot for DBSCAN')
plt.xlabel('Data Points sorted by distance')
plt.ylabel('4th Nearest Neighbor Distance')
plt.show()

# %%
from sklearn.cluster import DBSCAN

# Assuming you've chosen an appropriate value for `eps`
dbscan = DBSCAN(eps=0.2, min_samples=5)  # Tune min_samples based on your data
dbscan_clusters = dbscan.fit_predict(bp_clustering)

# Check how many clusters and how many outliers (noise points)
n_clusters = len(set(dbscan_clusters)) - (1 if -1 in dbscan_clusters else 0)
n_noise = list(dbscan_clusters).count(-1)
print(f'Estimated number of clusters: {n_clusters}')
print(f'Estimated number of noise points: {n_noise}')
# Out:
# Estimated number of clusters: 5
# Estimated number of noise points: 46

# %%
# Filter out noise points for silhouette score (-1 represents noise)
if n_clusters > 1:
    valid_clusters = dbscan_clusters[dbscan_clusters != -1]
    valid_features = bp_clustering[dbscan_clusters != -1]

    sil_score = silhouette_score(valid_features, valid_clusters)
    print(f'Silhouette Score for DBSCAN: {sil_score}')
else:
    print("Not enough clusters for Silhouette Score")
# Out:
# Silhouette Score for DBSCAN: 0.1512372175477581

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Assuming features_list_scaled contains your scaled feature data
# Reduce dimensionality to 2D for visualization
pca = PCA(n_components=2)
features_pca = pca.fit_transform(bp_clustering)

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=0.2, min_samples=5)  # Adjust 'eps' and 'min_samples' as needed
dbscan_clusters = dbscan.fit_predict(bp_clustering)

# Separate the noise (cluster -1) from the other clusters
core_samples_mask = dbscan_clusters != -1
noise_samples_mask = dbscan_clusters == -1

# Plot core clusters
plt.figure(figsize=(10, 6))
plt.scatter(features_pca[core_samples_mask, 0], features_pca[core_samples_mask, 1], 
            c=dbscan_clusters[core_samples_mask], cmap='viridis', s=50, label='Clusters')

# Plot noise samples
plt.scatter(features_pca[noise_samples_mask, 0], features_pca[noise_samples_mask, 1], 
            c='red', s=50, label='Noise', marker='x')

plt.colorbar()
plt.legend()
plt.title('DBSCAN Clustering (Noise in Red) Visualized with PCA')
plt.show()

# %% [markdown]
# _______

# %% [markdown]
# # Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
# List to store silhouette scores for different number of clusters
sil_scores = []

# Range of cluster numbers to test
cluster_range = range(2, 11)

for n_clusters in cluster_range:
    agglo = AgglomerativeClustering(n_clusters=n_clusters)
    agglo_clusters = agglo.fit_predict(bp_clustering)
    
    # Calculate the silhouette score
    sil_score = silhouette_score(bp_clustering, agglo_clusters)
    sil_scores.append(sil_score)

# Plot the silhouette scores for different cluster numbers
plt.plot(cluster_range, sil_scores, marker='o')
plt.title('Silhouette Score for Agglomerative Clustering')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
# Apply PCA to reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
features_pca = pca.fit_transform(bp_clustering)

# Apply KMeans on the original feature list
agglo = AgglomerativeClustering(n_clusters=3)
clusters = agglo.fit_predict(bp_clustering)

# Now visualize in 2D after PCA
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=clusters, cmap='viridis')
plt.colorbar()
plt.title('Agglomerative Clustering Visualized with PCA')
plt.show()

# %% [markdown]
# ________

# %% [markdown]
# # GMM Clustering

# %%
from sklearn.mixture import GaussianMixture

# %%
# Lists to store scores for different numbers of clusters
sil_scores = []
aic_scores = []
bic_scores = []

# Range of cluster numbers to test
cluster_range = range(2, 11)  # Try different numbers of clusters

for n_clusters in cluster_range:
    gmm = GaussianMixture(n_components=n_clusters, random_state=42)
    
    # Fit the GMM model
    gmm_clusters = gmm.fit_predict(bp_clustering)
    
    # Calculate and append the silhouette score
    sil_score = silhouette_score(bp_clustering, gmm_clusters)
    sil_scores.append(sil_score)
    
    # Append AIC and BIC scores
    aic_scores.append(gmm.aic(bp_clustering))
    bic_scores.append(gmm.bic(bp_clustering))

# Plot the results
plt.figure(figsize=(15, 5))

# Plot Silhouette Scores
plt.subplot(1, 3, 1)
plt.plot(cluster_range, sil_scores, marker='o')
plt.title('Silhouette Score for GMM')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')

# Plot AIC Scores
plt.subplot(1, 3, 2)
plt.plot(cluster_range, aic_scores, marker='o', label='AIC', color='orange')
plt.title('AIC for GMM')
plt.xlabel('Number of clusters')
plt.ylabel('AIC Score')

# Plot BIC Scores
plt.subplot(1, 3, 3)
plt.plot(cluster_range, bic_scores, marker='o', label='BIC', color='green')
plt.title('BIC for GMM')
plt.xlabel('Number of clusters')
plt.ylabel('BIC Score')

plt.tight_layout()
plt.show()

# %%
# Apply PCA to reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
features_pca = pca.fit_transform(bp_clustering)

# Apply KMeans on the original feature list
gmm = GaussianMixture(n_components=5)
clusters = gmm.fit_predict(bp_clustering)

# Now visualize in 2D after PCA
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=clusters, cmap='viridis')
plt.colorbar()
plt.title('GMM Clustering Visualized with PCA')
plt.show()

# %% [markdown]
# ____________

# %% [markdown]
# # Spectral Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering
from sklearn.metrics import silhouette_score
from sklearn.neighbors import kneighbors_graph
from sklearn.manifold import spectral_embedding

# Define a function to calculate eigenvalue gap
def calculate_eigenvalue_gaps(bp_clustering, cluster_range):
    eigenvalue_gaps = []
    
    for n_clusters in cluster_range:
        # Create the affinity matrix using k-nearest neighbors graph
        affinity_matrix = kneighbors_graph(bp_clustering, n_neighbors=10).toarray()
        
        # Compute the spectral embedding (eigenvalues of Laplacian matrix)
        embedding = spectral_embedding(affinity_matrix, n_components=n_clusters)
        eigenvalues = np.linalg.svd(embedding, compute_uv=False)  # Get singular values (eigenvalues)
        
        # Compute the eigenvalue gaps
        eigenvalue_gaps.append(np.diff(eigenvalues).max())  # Largest gap between consecutive eigenvalues
    
    return eigenvalue_gaps

# List to store silhouette scores for different number of clusters
sil_scores = []

# Range of cluster numbers to test
cluster_range = range(2, 11)

# Calculate the eigenvalue gaps
eigenvalue_gaps = calculate_eigenvalue_gaps(bp_clustering, cluster_range)

# Perform spectral clustering and calculate silhouette scores
for n_clusters in cluster_range:
    # Apply Spectral Clustering
    spectral = SpectralClustering(n_clusters=n_clusters, affinity='nearest_neighbors', random_state=42)
    cluster_labels = spectral.fit_predict(bp_clustering)
    
    # Calculate silhouette score
    sil_score = silhouette_score(bp_clustering, cluster_labels)
    sil_scores.append(sil_score)

# Plot the eigenvalue gaps and silhouette scores side by side
plt.figure(figsize=(12, 5))

# Plot Eigenvalue Gaps
plt.subplot(1, 2, 1)
plt.plot(cluster_range, eigenvalue_gaps, marker='o', color='blue')
plt.title('Eigenvalue Gaps for Spectral Clustering')
plt.xlabel('Number of clusters')
plt.ylabel('Eigenvalue Gap')

# Plot Silhouette Scores
plt.subplot(1, 2, 2)
plt.plot(cluster_range, sil_scores, marker='o', color='green')
plt.title('Silhouette Score for Spectral Clustering')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:310: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# c:\Users\Shank\anaconda3\envs\dsenv3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
# Apply Clustering on the original feature list
spectral = SpectralClustering(n_components=4)
clusters = spectral.fit_predict(bp_clustering)

# %%
# Apply PCA to reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
features_pca = pca.fit_transform(bp_clustering)

# Now visualize in 2D after PCA
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=clusters, cmap='viridis')
plt.colorbar()
plt.title('Spectral Clustering Visualized with PCA')
plt.show()

# %% [markdown]
# ______

# %% [markdown]
# # Mean Shift Clustering

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth

# Estimate bandwidth for MeanShift algorithm (you can also manually set it)
bandwidth = estimate_bandwidth(bp_clustering, quantile=0.2, n_samples=500)

# Apply Mean Shift clustering
mean_shift = MeanShift(bandwidth=bandwidth, bin_seeding=True)
mean_shift_clusters = mean_shift.fit_predict(bp_clustering)

# Print the number of clusters found
n_clusters = len(np.unique(mean_shift_clusters))
print(f'Number of clusters found: {n_clusters}')
# Out:
# Number of clusters found: 8

# %%
sil_score = silhouette_score(bp_clustering, mean_shift_clusters)
print(f'Silhouette Score for Mean Shift: {sil_score}')
# Out:
# Silhouette Score for Mean Shift: 0.4736756972443318

# %%
# Apply PCA to reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
features_pca = pca.fit_transform(bp_clustering)

# Now visualize in 2D after PCA
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=mean_shift_clusters, cmap='viridis')
plt.colorbar()
plt.title('Mean Shift Clustering Visualized with PCA')
plt.show()

# %% [markdown]
# ____________

# %% [markdown]
# # MiniBatch KMeans Clustering

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
# Range of cluster numbers to test
cluster_range = range(2, 15)

# Lists to store inertia and silhouette scores
inertia_scores = []
sil_scores = []

# Iterate over the cluster range
for n_clusters in cluster_range:
    # Initialize MiniBatch KMeans
    mbkmeans = MiniBatchKMeans(n_clusters=n_clusters, batch_size=10, random_state=42)
    
    # Fit the model
    mbkmeans.fit(bp_clustering)
    
    # Append the inertia (for the elbow method)
    inertia_scores.append(mbkmeans.inertia_)
    
    # Predict cluster labels and calculate the silhouette score
    cluster_labels = mbkmeans.predict(bp_clustering)
    sil_score = silhouette_score(bp_clustering, cluster_labels)
    sil_scores.append(sil_score)

# Plotting the Elbow Test and Silhouette Score Test side by side
plt.figure(figsize=(12, 5))

# Elbow Method (Inertia)
plt.subplot(1, 2, 1)
plt.plot(cluster_range, inertia_scores, marker='o')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.grid(True)

# Silhouette Score Test
plt.subplot(1, 2, 2)
plt.plot(cluster_range, sil_scores, marker='o', color='green')
plt.title('Silhouette Score for Optimal Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Apply PCA to reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
features_pca = pca.fit_transform(bp_clustering)

# Apply KMeans on the original feature list
mbkmeans = MiniBatchKMeans(n_clusters=4,batch_size=10,random_state=42)
clusters = mbkmeans.fit_predict(bp_clustering)

# Now visualize in 2D after PCA
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=clusters, cmap='viridis')
plt.colorbar()
plt.title('GMM Clustering Visualized with PCA')
plt.show()

# %% [markdown]
# ____

# %% [markdown]
# # Picking a Model
#
# KMeans/MiniBatches KMeans

# %%
sampled_data = bp_track.sample(n=50000, random_state=42)
bp_clustering = sampled_data.drop(columns='broad_genre', axis=1)
scaler = StandardScaler()

bp_clustering = scaler.fit_transform(bp_clustering)

# %%
sil_scores = []

# Range of cluster numbers to test
cluster_range = range(4, 9)

for n_clusters in cluster_range:
    # Apply KMeans on the original feature list
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    clusters = kmeans.fit_predict(bp_clustering)
    
    # Calculate the silhouette score
    sil_score = silhouette_score(bp_clustering, clusters)
    sil_scores.append(sil_score)

# Find the number of clusters with the highest silhouette score
peak_silo = cluster_range[sil_scores.index(max(sil_scores))]

print(f"The optimal number of clusters is: {peak_silo}")
# Out:
# The optimal number of clusters is: 8

# %%
bp = bp_track.dropna().drop(columns='broad_genre',axis=1)

# %%
bp = scaler.fit_transform(bp)

# %%
# Use the peak_silo number of clusters for final model
mbkmeans = MiniBatchKMeans(n_clusters=peak_silo, batch_size=5000, random_state=42,verbose=1) 
mbkmeans_clusters = mbkmeans.fit_predict(bp)
# Out:
# Init 1/1 with method k-means++
# Inertia for init 1/1: 7110.567902661702
# Minibatch step 1/213581: mean batch inertia: 0.4493946906449505
# Minibatch step 2/213581: mean batch inertia: 0.4072545880996592, ewa inertia: 0.4072545880996592
# Minibatch step 3/213581: mean batch inertia: 0.3628372001422164, ewa inertia: 0.4072129951943939
# Minibatch step 4/213581: mean batch inertia: 0.37609184845772936, ewa inertia: 0.4071838530280602
# Minibatch step 5/213581: mean batch inertia: 0.378680693895331, ewa inertia: 0.40715716237261906
# Minibatch step 6/213581: mean batch inertia: 0.36661954162717336, ewa inertia: 0.4071192025218291
# Minibatch step 7/213581: mean batch inertia: 0.3876406175331579, ewa inertia: 0.4071009625717242
# Minibatch step 8/213581: mean batch inertia: 0.34554220943913294, ewa inertia: 0.4070433183133597
# Minibatch step 9/213581: mean batch inertia: 0.35342843097048016, ewa inertia: 0.40699311277375894
# Minibatch step 10/213581: mean batch inertia: 0.3187128437919044, ewa inertia: 0.40691044620930283
# Minibatch step 11/213581: mean batch inertia: 0.3368291072839748, ewa inertia: 0.40684482131272903
# Minibatch step 12/213581: mean batch inertia: 0.3339917656898817, ewa inertia: 0.4067766009517364
# Minibatch step 13/213581: mean batch inertia: 0.3458972656803265, ewa inertia: 0.4067195929073421
# Minibatch step 14/213581: mean batch inertia: 0.352113797995277, ewa inertia: 0.40666845947156044
# Minibatch step 15/213581: mean batch inertia: 0.3047611442609684, ewa inertia: 0.4065730323989137
# Minibatch step 16/213581: mean batch inertia: 0.29238787799741356, ewa inertia: 0.406466108229616
# Minibatch step 17/213581: mean batch inertia: 0.32097003973074256, ewa inertia: 0.40638604881952567
# Minibatch step 18/213581: mean batch inertia: 0.34336266465540355, ewa inertia: 0.4063270330653902
# Minibatch step 19/213581: mean batch inertia: 0.31459345570879754, ewa inertia: 0.4062411327869611
# Minibatch step 20/213581: mean batch inertia: 0.36603374732022087, ewa inertia: 0.4062034821719298
# Minibatch step 21/213581: mean batch inertia: 0.3450048521273301, ewa inertia: 0.4061461751365803
# Minibatch step 22/213581: mean batch inertia: 0.3354149638239841, ewa inertia: 0.40607994169272627
# Minibatch step 23/213581: mean batch inertia: 0.3117844524136447, ewa inertia: 0.40599164241325747
# Minibatch step 24/213581: mean batch inertia: 0.35019205486084076, ewa inertia: 0.4059393910975985
# Minibatch step 25/213581: mean batch inertia: 0.3352597983209585, ewa inertia: 0.4058732059898798
# Minibatch step 26/213581: mean batch inertia: 0.3286350726865516, ewa inertia: 0.40580087939641984
# Minibatch step 27/213581: mean batch inertia: 0.314808556129503, ewa inertia: 0.40571567323605007
# Minibatch step 28/213581: mean batch inertia: 0.3358687610552207, ewa inertia: 0.4056502678591244
# Minibatch step 29/213581: mean batch inertia: 0.3083990832375229, ewa inertia: 0.40555920083571506
# Minibatch step 30/213581: mean batch inertia: 0.29136938367992393, ewa inertia: 0.4054522723001657
# Minibatch step 31/213581: mean batch inertia: 0.340587153079499, ewa inertia: 0.40539153192611777
# Minibatch step 32/213581: mean batch inertia: 0.3415031571811755, ewa inertia: 0.40533170618578235
# Minibatch step 33/213581: mean batch inertia: 0.34054729433094433, ewa inertia: 0.4052710413869534
# Minibatch step 34/213581: mean batch inertia: 0.339230791200796, ewa inertia: 0.40520920060801524
# Minibatch step 35/213581: mean batch inertia: 0.3105497291013126, ewa inertia: 0.40512056049179296
# Minibatch step 36/213581: mean batch inertia: 0.3211945489889541, ewa inertia: 0.4050419712994462
# Minibatch step 37/213581: mean batch inertia: 0.3353451809998669, ewa inertia: 0.4049767064982156
# Minibatch step 38/213581: mean batch inertia: 0.3222522629463628, ewa inertia: 0.40489924246662795
# Minibatch step 39/213581: mean batch inertia: 0.3117656368200098, ewa inertia: 0.4048120311871087
# Minibatch step 40/213581: mean batch inertia: 0.3182409750516148, ewa inertia: 0.4047309651473855
# Minibatch step 41/213581: mean batch inertia: 0.30485236087412887, ewa inertia: 0.4046374377808158
# Minibatch step 42/213581: mean batch inertia: 0.33877243344919167, ewa inertia: 0.4045757611039233
# Minibatch step 43/213581: mean batch inertia: 0.30899336261866406, ewa inertia: 0.40448625674925404
# Minibatch step 44/213581: mean batch inertia: 0.3185557207185068, ewa inertia: 0.40440579049923625
# Minibatch step 45/213581: mean batch inertia: 0.3181188723677843, ewa inertia: 0.404324990529303
# Minibatch step 46/213581: mean batch inertia: 0.30903220017610605, ewa inertia: 0.4042357573667086
# Minibatch step 47/213581: mean batch inertia: 0.32385396289370777, ewa inertia: 0.40416048701614743
# Minibatch step 48/213581: mean batch inertia: 0.34665283949765546, ewa inertia: 0.4041066362553247
# Minibatch step 49/213581: mean batch inertia: 0.30067800664872646, ewa inertia: 0.40400978460801346
# Minibatch step 50/213581: mean batch inertia: 0.32760484005488605, ewa inertia: 0.40393823822118763
# Minibatch step 51/213581: mean batch inertia: 0.3426417017787637, ewa inertia: 0.40388083950526626
# Minibatch step 52/213581: mean batch inertia: 0.3239760551941748, ewa inertia: 0.40380601583199494
# Minibatch step 53/213581: mean batch inertia: 0.3217343296798959, ewa inertia: 0.4037291630492434
# Minibatch step 54/213581: mean batch inertia: 0.3089587141389987, ewa inertia: 0.4036404190126231
# Minibatch step 55/213581: mean batch inertia: 0.30911890045076873, ewa inertia: 0.4035519080769769
# Minibatch step 56/213581: mean batch inertia: 0.3328084640905045, ewa inertia: 0.40348566317831946
# Minibatch step 57/213581: mean batch inertia: 0.3264702902700442, ewa inertia: 0.4034135451800163
# Minibatch step 58/213581: mean batch inertia: 0.3225110249911326, ewa inertia: 0.4033377872164647
# Minibatch step 59/213581: mean batch inertia: 0.3073911887466511, ewa inertia: 0.403247941821132
# Minibatch step 60/213581: mean batch inertia: 0.32456465921412525, ewa inertia: 0.4031742619747941
# Minibatch step 61/213581: mean batch inertia: 0.29530458905483636, ewa inertia: 0.40307325168821323
# Minibatch step 62/213581: mean batch inertia: 0.32121089690528964, ewa inertia: 0.40299659492553863
# Minibatch step 63/213581: mean batch inertia: 0.2887204846812056, ewa inertia: 0.40288958558424126
# Minibatch step 64/213581: mean batch inertia: 0.2993497917018205, ewa inertia: 0.40279262984154285
# Minibatch step 65/213581: mean batch inertia: 0.31910482379542826, ewa inertia: 0.4027142637072697
# Minibatch step 66/213581: mean batch inertia: 0.3184710973915877, ewa inertia: 0.4026353775278489
# Minibatch step 67/213581: mean batch inertia: 0.33366881525196435, ewa inertia: 0.40257079651975447
# Minibatch step 68/213581: mean batch inertia: 0.3287412498847919, ewa inertia: 0.4025016617623953
# Minibatch step 69/213581: mean batch inertia: 0.3154497797970684, ewa inertia: 0.40242014547235105
# Minibatch step 70/213581: mean batch inertia: 0.2997048057220057, ewa inertia: 0.4023239617570993
# Minibatch step 71/213581: mean batch inertia: 0.3067415976894157, ewa inertia: 0.402234457434659
# Minibatch step 72/213581: mean batch inertia: 0.3296091425219657, ewa inertia: 0.40216645033244225
# Minibatch step 73/213581: mean batch inertia: 0.3082555267256377, ewa inertia: 0.40207851116427923
# Minibatch step 74/213581: mean batch inertia: 0.32006048819983257, ewa inertia: 0.4020017086322962
# Minibatch step 75/213581: mean batch inertia: 0.3392676527860123, ewa inertia: 0.40194296380821465
# Minibatch step 76/213581: mean batch inertia: 0.3467546057150744, ewa inertia: 0.40189128485419523
# Minibatch step 77/213581: mean batch inertia: 0.298271277699133, ewa inertia: 0.40179425399895186
# Minibatch step 78/213581: mean batch inertia: 0.3357929106911959, ewa inertia: 0.4017324496528203
# Minibatch step 79/213581: mean batch inertia: 0.3256061180685844, ewa inertia: 0.4016611641620839
# Minibatch step 80/213581: mean batch inertia: 0.3417325118203691, ewa inertia: 0.40160504634709865
# Minibatch step 81/213581: mean batch inertia: 0.32497146950201183, ewa inertia: 0.40153328586661047
# Minibatch step 82/213581: mean batch inertia: 0.3098440456596714, ewa inertia: 0.40144742710595066
# Minibatch step 83/213581: mean batch inertia: 0.32174414101877985, ewa inertia: 0.4013727921177174
# Minibatch step 84/213581: mean batch inertia: 0.33038717802840756, ewa inertia: 0.4013063204484504
# Minibatch step 85/213581: mean batch inertia: 0.3330920159163775, ewa inertia: 0.40124244386235175
# Minibatch step 86/213581: mean batch inertia: 0.33717846506550536, ewa inertia: 0.40118245368455097
# Minibatch step 87/213581: mean batch inertia: 0.32410228078829145, ewa inertia: 0.40111027500686336
# Minibatch step 88/213581: mean batch inertia: 0.3199658958629709, ewa inertia: 0.4010342905640642
# Minibatch step 89/213581: mean batch inertia: 0.3014508468748787, ewa inertia: 0.4009410395889433
# Minibatch step 90/213581: mean batch inertia: 0.30585287325558935, ewa inertia: 0.40085199803841487
# Minibatch step 91/213581: mean batch inertia: 0.31832156689890206, ewa inertia: 0.40077471568207335
# Minibatch step 92/213581: mean batch inertia: 0.30826205566761516, ewa inertia: 0.4006880858625192
# Minibatch step 93/213581: mean batch inertia: 0.320016055828053, ewa inertia: 0.4006125437323517
# Minibatch step 94/213581: mean batch inertia: 0.32077515800133705, ewa inertia: 0.4005377831718136
# Minibatch step 95/213581: mean batch inertia: 0.32084240997966174, ewa inertia: 0.4004631555932978
# Minibatch step 96/213581: mean batch inertia: 0.3101164766568428, ewa inertia: 0.4003785540210118
# Minibatch step 97/213581: mean batch inertia: 0.3145886091664462, ewa inertia: 0.40029821942203747
# Minibatch step 98/213581: mean batch inertia: 0.34067858331904743, ewa inertia: 0.4002423909730805
# Minibatch step 99/213581: mean batch inertia: 0.318300318706235, ewa inertia: 0.4001656595621227
# Minibatch step 100/213581: mean batch inertia: 0.3219481296114344, ewa inertia: 0.400092415851429
# Minibatch step 101/213581: mean batch inertia: 0.30843971202468395, ewa inertia: 0.4000065913038166
# Minibatch step 102/213581: mean batch inertia: 0.32019107222643994, ewa inertia: 0.39993185121944097
# Minibatch step 103/213581: mean batch inertia: 0.31278489720944747, ewa inertia: 0.39985024590294266
# Minibatch step 104/213581: mean batch inertia: 0.31435542789530513, ewa inertia: 0.3997701876638253
# Minibatch step 105/213581: mean batch inertia: 0.31433133170384636, ewa inertia: 0.39969018182815297
# Minibatch step 106/213581: mean batch inertia: 0.3488366186298146, ewa inertia: 0.39964256202127607
# Minibatch step 107/213581: mean batch inertia: 0.3169623455467934, ewa inertia: 0.3995651394043849
# Minibatch step 108/213581: mean batch inertia: 0.3174444630490276, ewa inertia: 0.3994882407466961
# Minibatch step 109/213581: mean batch inertia: 0.33720080199029995, ewa inertia: 0.3994299141395148
# Minibatch step 110/213581: mean batch inertia: 0.30490629116208007, ewa inertia: 0.39934140123327194
# Minibatch step 111/213581: mean batch inertia: 0.29898616851769627, ewa inertia: 0.3992474275468586
# Minibatch step 112/213581: mean batch inertia: 0.3050030413150103, ewa inertia: 0.39915917612081614
# Minibatch step 113/213581: mean batch inertia: 0.31067205499125256, ewa inertia: 0.39907631585785186
# Minibatch step 114/213581: mean batch inertia: 0.29130745632358473, ewa inertia: 0.3989753999739766
# Minibatch step 115/213581: mean batch inertia: 0.29772092155268637, ewa inertia: 0.3988805842245071
# Minibatch step 116/213581: mean batch inertia: 0.3225344453016908, ewa inertia: 0.3988090929038867
# Minibatch step 117/213581: mean batch inertia: 0.30370339465606927, ewa inertia: 0.3987200349362908
# Minibatch step 118/213581: mean batch inertia: 0.30176550960714155, ewa inertia: 0.3986292457077365
# Minibatch step 119/213581: mean batch inertia: 0.3354310660288033, ewa inertia: 0.39857006627325825
# Minibatch step 120/213581: mean batch inertia: 0.30977650966373477, ewa inertia: 0.3984869190609151
# Minibatch step 121/213581: mean batch inertia: 0.3083943755238451, ewa inertia: 0.3984025554636672
# Minibatch step 122/213581: mean batch inertia: 0.2991016235293441, ewa inertia: 0.3983095690354996
# Minibatch step 123/213581: mean batch inertia: 0.29879902075842507, ewa inertia: 0.39821638632040274
# Minibatch step 124/213581: mean batch inertia: 0.30350954048007633, ewa inertia: 0.3981277018423604
# Minibatch step 125/213581: mean batch inertia: 0.33069110624602455, ewa inertia: 0.39806455351101916
# Minibatch step 126/213581: mean batch inertia: 0.309173576440843, ewa inertia: 0.3979813150731408
# Minibatch step 127/213581: mean batch inertia: 0.30733508039943225, ewa inertia: 0.3978964329937387
# Minibatch step 128/213581: mean batch inertia: 0.31418832714108563, ewa inertia: 0.39781804785051506
# Minibatch step 129/213581: mean batch inertia: 0.31125013339900465, ewa inertia: 0.3977369847526975
# Minibatch step 130/213581: mean batch inertia: 0.3112397795415484, ewa inertia: 0.39765598786774997
# Minibatch step 131/213581: mean batch inertia: 0.31721674650109544, ewa inertia: 0.3975806637233186
# Minibatch step 132/213581: mean batch inertia: 0.30091566177063844, ewa inertia: 0.3974901456074731
# Minibatch step 133/213581: mean batch inertia: 0.327850541846226, ewa inertia: 0.3974249343563133
# Minibatch step 134/213581: mean batch inertia: 0.308200589812523, ewa inertia: 0.3973413837496563
# Minibatch step 135/213581: mean batch inertia: 0.3332374182943578, ewa inertia: 0.3972813561279315
# Minibatch step 136/213581: mean batch inertia: 0.29401688419344046, ewa inertia: 0.39718465819957616
# Minibatch step 137/213581: mean batch inertia: 0.33837797017026994, ewa inertia: 0.3971295910036728
# Minibatch step 138/213581: mean batch inertia: 0.34427940878549596, ewa inertia: 0.3970801015419251
# Minibatch step 139/213581: mean batch inertia: 0.32352319005205465, ewa inertia: 0.39701122208295875
# Minibatch step 140/213581: mean batch inertia: 0.32495639588452835, ewa inertia: 0.39694374919232306
# Minibatch step 141/213581: mean batch inertia: 0.30074760709582515, ewa inertia: 0.39685367012173617
# Minibatch step 142/213581: mean batch inertia: 0.31083758511400167, ewa inertia: 0.3967731237627642
# Minibatch step 143/213581: mean batch inertia: 0.35456725256854404, ewa inertia: 0.39673360174485756
# Minibatch step 144/213581: mean batch inertia: 0.3144345096673414, ewa inertia: 0.39665653601682604
# Minibatch step 145/213581: mean batch inertia: 0.3161660442568424, ewa inertia: 0.39658116388099185
# Minibatch step 146/213581: mean batch inertia: 0.3345110953651313, ewa inertia: 0.3965230408215706
# Minibatch step 147/213581: mean batch inertia: 0.3567713118836516, ewa inertia: 0.3964858168880644
# Minibatch step 148/213581: mean batch inertia: 0.326936976197779, ewa inertia: 0.39642069062839075
# Minibatch step 149/213581: mean batch inertia: 0.33613835901027256, ewa inertia: 0.3963642416244429
# Minibatch step 150/213581: mean batch inertia: 0.3111473750446889, ewa inertia: 0.3962844436619411
# Minibatch step 151/213581: mean batch inertia: 0.3291302486254217, ewa inertia: 0.3962215597734289
# Minibatch step 152/213581: mean batch inertia: 0.31219178428324046, ewa inertia: 0.3961428734154023
# Minibatch step 153/213581: mean batch inertia: 0.34978223564158784, ewa inertia: 0.3960994608307449
# Minibatch step 154/213581: mean batch inertia: 0.3167754415197633, ewa inertia: 0.39602518099187584
# Minibatch step 155/213581: mean batch inertia: 0.3214769291172721, ewa inertia: 0.39595537323143565
# Minibatch step 156/213581: mean batch inertia: 0.3098404779700067, ewa inertia: 0.3958747343455118
# Minibatch step 157/213581: mean batch inertia: 0.31986591700635875, ewa inertia: 0.3958035588963399
# Minibatch step 158/213581: mean batch inertia: 0.30277101445974625, ewa inertia: 0.3957164422515915
# Minibatch step 159/213581: mean batch inertia: 0.32632346777979326, ewa inertia: 0.3956514619466702
# Minibatch step 160/213581: mean batch inertia: 0.3071970897998951, ewa inertia: 0.395568632350195
# Minibatch step 161/213581: mean batch inertia: 0.33151907627531085, ewa inertia: 0.3955086556779815
# Minibatch step 162/213581: mean batch inertia: 0.3252129256483915, ewa inertia: 0.395442830023342
# Minibatch step 163/213581: mean batch inertia: 0.32798604486501537, ewa inertia: 0.39537966278628434
# Minibatch step 164/213581: mean batch inertia: 0.30011867270340203, ewa inertia: 0.3952904594017947
# Minibatch step 165/213581: mean batch inertia: 0.3329830108524165, ewa inertia: 0.39523211405723463
# Minibatch step 166/213581: mean batch inertia: 0.32476247150821086, ewa inertia: 0.3951661255490984
# Minibatch step 167/213581: mean batch inertia: 0.3353718017262883, ewa inertia: 0.39511013352073904
# Minibatch step 168/213581: mean batch inertia: 0.3370803954605547, ewa inertia: 0.3950557938688888
# Minibatch step 169/213581: mean batch inertia: 0.3233062190515257, ewa inertia: 0.39498860681882947
# Minibatch step 170/213581: mean batch inertia: 0.311959980303301, ewa inertia: 0.39491085794714265
# Minibatch step 171/213581: mean batch inertia: 0.3639127827360433, ewa inertia: 0.39488183102626884
# Minibatch step 172/213581: mean batch inertia: 0.33657881418684904, ewa inertia: 0.39482723547331994
# Minibatch step 173/213581: mean batch inertia: 0.2941032628631473, ewa inertia: 0.39473291649502407
# Minibatch step 174/213581: mean batch inertia: 0.2970710669496986, ewa inertia: 0.3946414649206978
# Minibatch step 175/213581: mean batch inertia: 0.3285620984741771, ewa inertia: 0.3945795875128855
# Minibatch step 176/213581: mean batch inertia: 0.3121616820855872, ewa inertia: 0.3945024105267943
# Minibatch step 177/213581: mean batch inertia: 0.3168732049670013, ewa inertia: 0.3944297177291953
# Minibatch step 178/213581: mean batch inertia: 0.3189805090818805, ewa inertia: 0.39435906630343803
# Minibatch step 179/213581: mean batch inertia: 0.3390879349869966, ewa inertia: 0.3943073098397092
# Minibatch step 180/213581: mean batch inertia: 0.30998872223449253, ewa inertia: 0.39422835303500636
# Minibatch step 181/213581: mean batch inertia: 0.31342285586318547, ewa inertia: 0.39415268592481967
# Minibatch step 182/213581: mean batch inertia: 0.3327434830926637, ewa inertia: 0.3940951817069161
# Minibatch step 183/213581: mean batch inertia: 0.3085018473470583, ewa inertia: 0.39401503121605924
# Minibatch step 184/213581: mean batch inertia: 0.31403057477248214, ewa inertia: 0.3939401329369723
# Minibatch step 185/213581: mean batch inertia: 0.3145001181122424, ewa inertia: 0.3938657444786946
# Minibatch step 186/213581: mean batch inertia: 0.32601424558951364, ewa inertia: 0.39380220762758333
# Minibatch step 187/213581: mean batch inertia: 0.2928753939846962, ewa inertia: 0.39370769870682926
# Minibatch step 188/213581: mean batch inertia: 0.29882267687756897, ewa inertia: 0.39361884738293285
# Minibatch step 189/213581: mean batch inertia: 0.3258604410393923, ewa inertia: 0.39355539770465203
# Minibatch step 190/213581: mean batch inertia: 0.32844543865144044, ewa inertia: 0.39349442806003176
# Minibatch step 191/213581: mean batch inertia: 0.30540037406037773, ewa inertia: 0.39341193586922685
# Minibatch step 192/213581: mean batch inertia: 0.31563078930368704, ewa inertia: 0.39333910079248563
# Minibatch step 193/213581: mean batch inertia: 0.3296136777415686, ewa inertia: 0.3932794276418158
# Minibatch step 194/213581: mean batch inertia: 0.31985827824904706, ewa inertia: 0.3932106753118929
# Minibatch step 195/213581: mean batch inertia: 0.3422107197858708, ewa inertia: 0.39316291842171375
# Minibatch step 196/213581: mean batch inertia: 0.2812881513479452, ewa inertia: 0.39305815772320235
# Minibatch step 197/213581: mean batch inertia: 0.33516011546739166, ewa inertia: 0.39300394139267664
# Minibatch step 198/213581: mean batch inertia: 0.3240492470653041, ewa inertia: 0.39293937149785296
# Minibatch step 199/213581: mean batch inertia: 0.30311664210032024, ewa inertia: 0.3928552605573789
# Minibatch step 200/213581: mean batch inertia: 0.3258752667559841, ewa inertia: 0.39279253979271983
# Minibatch step 201/213581: mean batch inertia: 0.33199698149937146, ewa inertia: 0.39273561019796144
# Minibatch step 202/213581: mean batch inertia: 0.29885113428192367, ewa inertia: 0.39264769579569186
# Minibatch step 203/213581: mean batch inertia: 0.32714782355733873, ewa inertia: 0.392586361032299
# Minibatch step 204/213581: mean batch inertia: 0.3371279593445926, ewa inertia: 0.3925344292066416
# Minibatch step 205/213581: mean batch inertia: 0.3039904178368002, ewa inertia: 0.3924515156710631
# Minibatch step 206/213581: mean batch inertia: 0.3157559916718383, ewa inertia: 0.3923796971826138
# Minibatch step 207/213581: mean batch inertia: 0.30426874382584773, ewa inertia: 0.3922971891670746
# Minibatch step 208/213581: mean batch inertia: 0.3084528887092362, ewa inertia: 0.39221867648980246
# Minibatch step 209/213581: mean batch inertia: 0.315172340585501, ewa inertia: 0.392146529497427
# Minibatch step 210/213581: mean batch inertia: 0.3062088404375667, ewa inertia: 0.39206605654923815
# Minibatch step 211/213581: mean batch inertia: 0.31185117082423996, ewa inertia: 0.39199094249376915
# Minibatch step 212/213581: mean batch inertia: 0.2988682787370562, ewa inertia: 0.3919037414603497
# Minibatch step 213/213581: mean batch inertia: 0.3168661974800104, ewa inertia: 0.39183347552167935
# Minibatch step 214/213581: mean batch inertia: 0.3182118981601995, ewa inertia: 0.3917645355089166
# Minibatch step 215/213581: mean batch inertia: 0.30686112456868975, ewa inertia: 0.39168503106954433
# Minibatch step 216/213581: mean batch inertia: 0.3014922254520037, ewa inertia: 0.3916005735858388
# Minibatch step 217/213581: mean batch inertia: 0.3106254422977689, ewa inertia: 0.3915247476284967
# Minibatch step 218/213581: mean batch inertia: 0.3269354367480944, ewa inertia: 0.39146426552425473
# Minibatch step 219/213581: mean batch inertia: 0.32128488414401146, ewa inertia: 0.3913985488197038
# Minibatch step 220/213581: mean batch inertia: 0.30045761099115276, ewa inertia: 0.39131339077719435
# Minibatch step 221/213581: mean batch inertia: 0.3323871637802292, ewa inertia: 0.3912582116437551
# Minibatch step 222/213581: mean batch inertia: 0.2865859669979592, ewa inertia: 0.39116019546235276
# Minibatch step 223/213581: mean batch inertia: 0.3334654457156337, ewa inertia: 0.39110616949705246
# Minibatch step 224/213581: mean batch inertia: 0.31128363385808006, ewa inertia: 0.39103142284229536
# Minibatch step 225/213581: mean batch inertia: 0.33954804247393416, ewa inertia: 0.39098321326805274
# Minibatch step 226/213581: mean batch inertia: 0.3104711062191916, ewa inertia: 0.39090782089143666
# Minibatch step 227/213581: mean batch inertia: 0.32990747300910916, ewa inertia: 0.39085069952957163
# Minibatch step 228/213581: mean batch inertia: 0.34730030613503265, ewa inertia: 0.390809918487056
# Minibatch step 229/213581: mean batch inertia: 0.31593110675457214, ewa inertia: 0.3907398011869178
# Minibatch step 230/213581: mean batch inertia: 0.3270119902555761, ewa inertia: 0.39068012580021183
# Minibatch step 231/213581: mean batch inertia: 0.31586312784448284, ewa inertia: 0.39061006638313883
# Minibatch step 232/213581: mean batch inertia: 0.3338544708937079, ewa inertia: 0.3905569198516785
# Minibatch step 233/213581: mean batch inertia: 0.3389779052671965, ewa inertia: 0.39050862072455866
# Minibatch step 234/213581: mean batch inertia: 0.32163074371181166, ewa inertia: 0.3904441227622695
# Minibatch step 235/213581: mean batch inertia: 0.32805462448588835, ewa inertia: 0.39038570058548944
# Minibatch step 236/213581: mean batch inertia: 0.3254636317046316, ewa inertia: 0.39032490688318583
# Minibatch step 237/213581: mean batch inertia: 0.3112096538300172, ewa inertia: 0.39025082253521765
# Minibatch step 238/213581: mean batch inertia: 0.30629598292954563, ewa inertia: 0.3901722063479347
# Minibatch step 239/213581: mean batch inertia: 0.3213301383439381, ewa inertia: 0.3901077419175747
# Minibatch step 240/213581: mean batch inertia: 0.307176126395016, ewa inertia: 0.3900300838879933
# Minibatch step 241/213581: mean batch inertia: 0.3117303311304162, ewa inertia: 0.3899567631830059
# Minibatch step 242/213581: mean batch inertia: 0.3288342823722636, ewa inertia: 0.38989952745459305
# Minibatch step 243/213581: mean batch inertia: 0.32109162558137083, ewa inertia: 0.3898350950177542
# Minibatch step 244/213581: mean batch inertia: 0.32703467347552906, ewa inertia: 0.38977628804814296
# Minibatch step 245/213581: mean batch inertia: 0.30974633578990196, ewa inertia: 0.38970134716630067
# Minibatch step 246/213581: mean batch inertia: 0.3008828659905968, ewa inertia: 0.3896181766143338
# Minibatch step 247/213581: mean batch inertia: 0.3076029236269539, ewa inertia: 0.3895413766761861
# Minibatch step 248/213581: mean batch inertia: 0.3099291005470675, ewa inertia: 0.3894668269106266
# Minibatch step 249/213581: mean batch inertia: 0.29647446971888164, ewa inertia: 0.3893797478976334
# Minibatch step 250/213581: mean batch inertia: 0.3116682598654869, ewa inertia: 0.38930697804986925
# Minibatch step 251/213581: mean batch inertia: 0.34094924728173276, ewa inertia: 0.3892616953665064
# Minibatch step 252/213581: mean batch inertia: 0.2876936612272952, ewa inertia: 0.38916658600019294
# Minibatch step 253/213581: mean batch inertia: 0.3025409132376439, ewa inertia: 0.3890854688168906
# Minibatch step 254/213581: mean batch inertia: 0.2944888632661303, ewa inertia: 0.38899688756900497
# Minibatch step 255/213581: mean batch inertia: 0.27294911618649803, ewa inertia: 0.388888219225743
# Minibatch step 256/213581: mean batch inertia: 0.31400199335312334, ewa inertia: 0.38881809498292674
# Minibatch step 257/213581: mean batch inertia: 0.3204376015874995, ewa inertia: 0.38875406277584346
# Minibatch step 258/213581: mean batch inertia: 0.31103704739117, ewa inertia: 0.3886812877522088
# Minibatch step 259/213581: mean batch inertia: 0.3153398546166777, ewa inertia: 0.3886126100694205
# Minibatch step 260/213581: mean batch inertia: 0.31454879805429214, ewa inertia: 0.38854325594351646
# Minibatch step 261/213581: mean batch inertia: 0.3113429231735642, ewa inertia: 0.3884709647468701
# Minibatch step 262/213581: mean batch inertia: 0.3039208933109948, ewa inertia: 0.3883917911782943
# Minibatch step 263/213581: mean batch inertia: 0.3111560271283209, ewa inertia: 0.3883194668034279
# Minibatch step 264/213581: mean batch inertia: 0.3038049975841032, ewa inertia: 0.38824032657313895
# Minibatch step 265/213581: mean batch inertia: 0.32576421871802347, ewa inertia: 0.38818182329424616
# Minibatch step 266/213581: mean batch inertia: 0.32354948781113374, ewa inertia: 0.3881213009013176
# Minibatch step 267/213581: mean batch inertia: 0.3079693031132753, ewa inertia: 0.38804624573476854
# Minibatch step 268/213581: mean batch inertia: 0.3111548489197176, ewa inertia: 0.38797424382897194
# Minibatch step 269/213581: mean batch inertia: 0.3014347858651926, ewa inertia: 0.38789320737810623
# Minibatch step 270/213581: mean batch inertia: 0.31095407842243666, ewa inertia: 0.3878211607754354
# Minibatch step 271/213581: mean batch inertia: 0.30520825199288626, ewa inertia: 0.3877438011861688
# Minibatch step 272/213581: mean batch inertia: 0.3356178191939359, ewa inertia: 0.3876949898730646
# Minibatch step 273/213581: mean batch inertia: 0.3073023368313731, ewa inertia: 0.38761970935442647
# Minibatch step 274/213581: mean batch inertia: 0.3430576868704315, ewa inertia: 0.3875779810118823
# Minibatch step 275/213581: mean batch inertia: 0.3261695632991034, ewa inertia: 0.3875204775291726
# Minibatch step 276/213581: mean batch inertia: 0.34413442293548024, ewa inertia: 0.3874798503752238
# Minibatch step 277/213581: mean batch inertia: 0.3175363962026428, ewa inertia: 0.3874143545953704
# Minibatch step 278/213581: mean batch inertia: 0.3052823772416559, ewa inertia: 0.3873374453553089
# Minibatch step 279/213581: mean batch inertia: 0.3251867790303705, ewa inertia: 0.3872792468232587
# Minibatch step 280/213581: mean batch inertia: 0.34035521573438293, ewa inertia: 0.387235306671226
# Minibatch step 281/213581: mean batch inertia: 0.3141580715192291, ewa inertia: 0.3871668763861846
# Minibatch step 282/213581: mean batch inertia: 0.3130137944994631, ewa inertia: 0.3870974386670418
# Minibatch step 283/213581: mean batch inertia: 0.32486769988373737, ewa inertia: 0.3870391660907171
# Minibatch step 284/213581: mean batch inertia: 0.30866084572018665, ewa inertia: 0.38696577181419756
# Minibatch step 285/213581: mean batch inertia: 0.306861484545061, ewa inertia: 0.3868907613242759
# Minibatch step 286/213581: mean batch inertia: 0.3076720113047099, ewa inertia: 0.3868165800606691
# Minibatch step 287/213581: mean batch inertia: 0.2946792479036307, ewa inertia: 0.38673030170203454
# Minibatch step 288/213581: mean batch inertia: 0.299471726339281, ewa inertia: 0.3866485918621375
# Minibatch step 289/213581: mean batch inertia: 0.3112964137536496, ewa inertia: 0.38657803129678864
# Minibatch step 290/213581: mean batch inertia: 0.3282991940091969, ewa inertia: 0.38652345838582425
# Minibatch step 291/213581: mean batch inertia: 0.3165657282438023, ewa inertia: 0.38645794923780413
# Minibatch step 292/213581: mean batch inertia: 0.28809890099867086, ewa inertia: 0.38636584479935066
# Minibatch step 293/213581: mean batch inertia: 0.30974337673685975, ewa inertia: 0.3862940947212423
# Minibatch step 294/213581: mean batch inertia: 0.31128873295852183, ewa inertia: 0.3862238589183362
# Minibatch step 295/213581: mean batch inertia: 0.3332904555782394, ewa inertia: 0.3861742915274621
# Minibatch step 296/213581: mean batch inertia: 0.30438480239153853, ewa inertia: 0.3860977029969392
# Minibatch step 297/213581: mean batch inertia: 0.3012398881029162, ewa inertia: 0.3860182412541801
# Minibatch step 298/213581: mean batch inertia: 0.3320335951364739, ewa inertia: 0.38596768946860677
# Minibatch step 299/213581: mean batch inertia: 0.323128819773089, ewa inertia: 0.3859088464957438
# Minibatch step 300/213581: mean batch inertia: 0.32093859092427757, ewa inertia: 0.38584800767092065
# Minibatch step 301/213581: mean batch inertia: 0.30892210384879215, ewa inertia: 0.3857759734524028
# Minibatch step 302/213581: mean batch inertia: 0.3027130083010126, ewa inertia: 0.3856981924256593
# Minibatch step 303/213581: mean batch inertia: 0.29667854710859537, ewa inertia: 0.3856148335014927
# Minibatch step 304/213581: mean batch inertia: 0.3536813185667879, ewa inertia: 0.38558493062510707
# Minibatch step 305/213581: mean batch inertia: 0.3277830240131316, ewa inertia: 0.3855308043170007
# Minibatch step 306/213581: mean batch inertia: 0.3371367505496974, ewa inertia: 0.38548548762040263
# Minibatch step 307/213581: mean batch inertia: 0.3108712086011502, ewa inertia: 0.3854156180314557
# Minibatch step 308/213581: mean batch inertia: 0.305998640820018, ewa inertia: 0.3853412511458393
# Minibatch step 309/213581: mean batch inertia: 0.31540419490327215, ewa inertia: 0.38527576135707425
# Minibatch step 310/213581: mean batch inertia: 0.3086887715019364, ewa inertia: 0.3852040445011293
# Minibatch step 311/213581: mean batch inertia: 0.315600426145577, ewa inertia: 0.38513886694707866
# Minibatch step 312/213581: mean batch inertia: 0.31541538073109515, ewa inertia: 0.38507357714751356
# Minibatch step 313/213581: mean batch inertia: 0.31456232215456664, ewa inertia: 0.3850075496730509
# Minibatch step 314/213581: mean batch inertia: 0.3140717535866563, ewa inertia: 0.38494112465388125
# Minibatch step 315/213581: mean batch inertia: 0.3271143584833367, ewa inertia: 0.384886975067025
# Minibatch step 316/213581: mean batch inertia: 0.31004392879234405, ewa inertia: 0.38481689125803453
# Minibatch step 317/213581: mean batch inertia: 0.3070173844504751, ewa inertia: 0.38474403898857124
# Minibatch step 318/213581: mean batch inertia: 0.3097296902731827, ewa inertia: 0.3846737947701889
# Minibatch step 319/213581: mean batch inertia: 0.3358971230097946, ewa inertia: 0.3846281197861122
# Minibatch step 320/213581: mean batch inertia: 0.3291346655333969, ewa inertia: 0.3845761551368675
# Minibatch step 321/213581: mean batch inertia: 0.31989932790365094, ewa inertia: 0.38451559108140015
# Minibatch step 322/213581: mean batch inertia: 0.30748889888454306, ewa inertia: 0.3844434624835972
# Minibatch step 323/213581: mean batch inertia: 0.3277948790341161, ewa inertia: 0.38439041615932695
# Minibatch step 324/213581: mean batch inertia: 0.28077218668175874, ewa inertia: 0.38429338696871934
# Minibatch step 325/213581: mean batch inertia: 0.3095888538599454, ewa inertia: 0.3842234328649018
# Minibatch step 326/213581: mean batch inertia: 0.33143213208714584, ewa inertia: 0.3841739985403489
# Minibatch step 327/213581: mean batch inertia: 0.30661776060759816, ewa inertia: 0.38410137407039674
# Minibatch step 328/213581: mean batch inertia: 0.33412877208407726, ewa inertia: 0.3840545792047854
# Minibatch step 329/213581: mean batch inertia: 0.3134167413537783, ewa inertia: 0.38398843319681447
# Minibatch step 330/213581: mean batch inertia: 0.29687006805429145, ewa inertia: 0.3839068546512298
# Minibatch step 331/213581: mean batch inertia: 0.3180994651695046, ewa inertia: 0.3838452319254835
# Minibatch step 332/213581: mean batch inertia: 0.3238890945010949, ewa inertia: 0.3837890883731802
# Minibatch step 333/213581: mean batch inertia: 0.32768675696121596, ewa inertia: 0.38373655356501424
# Minibatch step 334/213581: mean batch inertia: 0.3151417697759782, ewa inertia: 0.3836723206941718
# Minibatch step 335/213581: mean batch inertia: 0.3375729459538724, ewa inertia: 0.3836291527589434
# Minibatch step 336/213581: mean batch inertia: 0.3025413259379766, ewa inertia: 0.3835532212723291
# Minibatch step 337/213581: mean batch inertia: 0.2911246692157682, ewa inertia: 0.3834666702123438
# Minibatch step 338/213581: mean batch inertia: 0.3174205256930637, ewa inertia: 0.38340482391389064
# Minibatch step 339/213581: mean batch inertia: 0.31986861630142466, ewa inertia: 0.3833453279465304
# Minibatch step 340/213581: mean batch inertia: 0.31322812876273654, ewa inertia: 0.38327966947003667
# Minibatch step 341/213581: mean batch inertia: 0.3109698902828259, ewa inertia: 0.3832119578387636
# Minibatch step 342/213581: mean batch inertia: 0.29376360289781533, ewa inertia: 0.3831281974664347
# Minibatch step 343/213581: mean batch inertia: 0.32731546800441236, ewa inertia: 0.3830759338445546
# Minibatch step 344/213581: mean batch inertia: 0.3405922210227975, ewa inertia: 0.3830361516528506
# Minibatch step 345/213581: mean batch inertia: 0.3187102719508596, ewa inertia: 0.3829759162283111
# Minibatch step 346/213581: mean batch inertia: 0.29754505080238003, ewa inertia: 0.3828959178750582
# Minibatch step 347/213581: mean batch inertia: 0.2940856317952334, ewa inertia: 0.38281275499706463
# Minibatch step 348/213581: mean batch inertia: 0.3071994365538886, ewa inertia: 0.3827419498971832
# Minibatch step 349/213581: mean batch inertia: 0.33857302582836274, ewa inertia: 0.3827005896560942
# Minibatch step 350/213581: mean batch inertia: 0.3168900938848338, ewa inertia: 0.382638964021586
# Minibatch step 351/213581: mean batch inertia: 0.3557061875462462, ewa inertia: 0.38261374388884106
# Minibatch step 352/213581: mean batch inertia: 0.31919236313812954, ewa inertia: 0.38255435544655164
# Minibatch step 353/213581: mean batch inertia: 0.30211260889411634, ewa inertia: 0.3824790289562381
# Minibatch step 354/213581: mean batch inertia: 0.311476157593268, ewa inertia: 0.38241254112708
# Minibatch step 355/213581: mean batch inertia: 0.28238050870113257, ewa inertia: 0.3823188700887882
# Minibatch step 356/213581: mean batch inertia: 0.33650620339815207, ewa inertia: 0.3822759706299672
# Minibatch step 357/213581: mean batch inertia: 0.31066197360836983, ewa inertia: 0.38220891053636963
# Minibatch step 358/213581: mean batch inertia: 0.3220223926503425, ewa inertia: 0.38215255125339964
# Minibatch step 359/213581: mean batch inertia: 0.3000473866238712, ewa inertia: 0.38207566712105273
# Minibatch step 360/213581: mean batch inertia: 0.31542611610544113, ewa inertia: 0.3820132557864641
# Minibatch step 361/213581: mean batch inertia: 0.3386033026374905, ewa inertia: 0.381972606253659
# Minibatch step 362/213581: mean batch inertia: 0.31768452702985195, ewa inertia: 0.38191240622588146
# Minibatch step 363/213581: mean batch inertia: 0.3274887168101531, ewa inertia: 0.3818614433155855
# Minibatch step 364/213581: mean batch inertia: 0.29829059111148665, ewa inertia: 0.3817831866981096
# Minibatch step 365/213581: mean batch inertia: 0.296042157869764, ewa inertia: 0.38170289790461237
# Minibatch step 366/213581: mean batch inertia: 0.3273765167628731, ewa inertia: 0.3816520261147989
# Minibatch step 367/213581: mean batch inertia: 0.3151748997584971, ewa inertia: 0.3815897762404593
# Minibatch step 368/213581: mean batch inertia: 0.3003623430488901, ewa inertia: 0.3815137140249838
# Minibatch step 369/213581: mean batch inertia: 0.3123067129781536, ewa inertia: 0.38144890786751695
# Minibatch step 370/213581: mean batch inertia: 0.309328696734704, ewa inertia: 0.38138137374974684
# Minibatch step 371/213581: mean batch inertia: 0.3043211456293051, ewa inertia: 0.3813092137485553
# Minibatch step 372/213581: mean batch inertia: 0.3012641730819338, ewa inertia: 0.3812342587377701
# Minibatch step 373/213581: mean batch inertia: 0.30982275403978593, ewa inertia: 0.38116738826009594
# Minibatch step 374/213581: mean batch inertia: 0.3118428349393107, ewa inertia: 0.381102472025454
# Minibatch step 375/213581: mean batch inertia: 0.3150705637017084, ewa inertia: 0.38104063905792274
# Minibatch step 376/213581: mean batch inertia: 0.29932952788400896, ewa inertia: 0.38096412392134077
# Minibatch step 377/213581: mean batch inertia: 0.3372891752321417, ewa inertia: 0.38092322624394837
# Minibatch step 378/213581: mean batch inertia: 0.3286983006854796, ewa inertia: 0.38087432227905693
# Minibatch step 379/213581: mean batch inertia: 0.3185755838392822, ewa inertia: 0.3808159850907343
# Minibatch step 380/213581: mean batch inertia: 0.3270667481851219, ewa inertia: 0.3807656537448019
# Minibatch step 381/213581: mean batch inertia: 0.30590688278520034, ewa inertia: 0.38069555521105247
# Minibatch step 382/213581: mean batch inertia: 0.33084538940932723, ewa inertia: 0.3806488749959611
# Minibatch step 383/213581: mean batch inertia: 0.2913877047206431, ewa inertia: 0.380565289905305
# Minibatch step 384/213581: mean batch inertia: 0.3333522468708058, ewa inertia: 0.3805210791194727
# Minibatch step 385/213581: mean batch inertia: 0.3041481594467309, ewa inertia: 0.3804495627210788
# Minibatch step 386/213581: mean batch inertia: 0.30648271285591466, ewa inertia: 0.38038029939154305
# Minibatch step 387/213581: mean batch inertia: 0.32870148015080597, ewa inertia: 0.3803319068063023
# Minibatch step 388/213581: mean batch inertia: 0.30801111814096216, ewa inertia: 0.3802641848656391
# Minibatch step 389/213581: mean batch inertia: 0.33584003631824655, ewa inertia: 0.3802225856296869
# Minibatch step 390/213581: mean batch inertia: 0.30763524567155653, ewa inertia: 0.3801546140876136
# Minibatch step 391/213581: mean batch inertia: 0.3196143749165334, ewa inertia: 0.3800979235763437
# Minibatch step 392/213581: mean batch inertia: 0.3058448336276945, ewa inertia: 0.3800283922086089
# Minibatch step 393/213581: mean batch inertia: 0.3130238799272797, ewa inertia: 0.3799656484845895
# Minibatch step 394/213581: mean batch inertia: 0.2960000087343691, ewa inertia: 0.37988702218393866
# Minibatch step 395/213581: mean batch inertia: 0.2813039520897097, ewa inertia: 0.37979470796908393
# Minibatch step 396/213581: mean batch inertia: 0.32387083865174854, ewa inertia: 0.37974234027468434
# Minibatch step 397/213581: mean batch inertia: 0.3229739881993451, ewa inertia: 0.3796891817978239
# Minibatch step 398/213581: mean batch inertia: 0.3185473558424411, ewa inertia: 0.3796319279544159
# Minibatch step 399/213581: mean batch inertia: 0.32750346821765614, ewa inertia: 0.37958311432112585
# Minibatch step 400/213581: mean batch inertia: 0.32723957229391215, ewa inertia: 0.3795340992825362
# Minibatch step 401/213581: mean batch inertia: 0.3183941276591379, ewa inertia: 0.379476847175544
# Minibatch step 402/213581: mean batch inertia: 0.2962545590999382, ewa inertia: 0.37939891695715283
# Minibatch step 403/213581: mean batch inertia: 0.2957648997661398, ewa inertia: 0.37932060119132455
# Minibatch step 404/213581: mean batch inertia: 0.29644209130576654, ewa inertia: 0.37924299289041546
# Minibatch step 405/213581: mean batch inertia: 0.3082407490958529, ewa inertia: 0.379176505648919
# Minibatch step 406/213581: mean batch inertia: 0.3429627607614603, ewa inertia: 0.3791425947205716
# Minibatch step 407/213581: mean batch inertia: 0.30297733904597984, ewa inertia: 0.3790712727809111
# Minibatch step 408/213581: mean batch inertia: 0.29143133257527437, ewa inertia: 0.37898920582699835
# Minibatch step 409/213581: mean batch inertia: 0.30896743419903666, ewa inertia: 0.378923636709863
# Minibatch step 410/213581: mean batch inertia: 0.3341054316313606, ewa inertia: 0.3788816684752659
# Minibatch step 411/213581: mean batch inertia: 0.3004659296920224, ewa inertia: 0.37880823915975453
# Minibatch step 412/213581: mean batch inertia: 0.3258156792152348, ewa inertia: 0.3787586163740192
# Minibatch step 413/213581: mean batch inertia: 0.2814896041368753, ewa inertia: 0.37866753265664477
# Minibatch step 414/213581: mean batch inertia: 0.2994385962672141, ewa inertia: 0.378593341854415
# Minibatch step 415/213581: mean batch inertia: 0.3153957422620129, ewa inertia: 0.3785341629631358
# Minibatch step 416/213581: mean batch inertia: 0.3131056182020877, ewa inertia: 0.3784728949915365
# Minibatch step 417/213581: mean batch inertia: 0.3032476865197638, ewa inertia: 0.3784024533218795
# Minibatch step 418/213581: mean batch inertia: 0.2965832503843142, ewa inertia: 0.3783258369670429
# Minibatch step 419/213581: mean batch inertia: 0.2913601091188477, ewa inertia: 0.37824440135261234
# Minibatch step 420/213581: mean batch inertia: 0.3606491575263526, ewa inertia: 0.3782279249828112
# Minibatch step 421/213581: mean batch inertia: 0.312582671904948, ewa inertia: 0.37816645408328425
# Minibatch step 422/213581: mean batch inertia: 0.3269188971430504, ewa inertia: 0.3781184653365589
# Minibatch step 423/213581: mean batch inertia: 0.3099325679935239, ewa inertia: 0.3780546153512483
# Minibatch step 424/213581: mean batch inertia: 0.3286338589943387, ewa inertia: 0.3780083372396389
# Minibatch step 425/213581: mean batch inertia: 0.3096855515606052, ewa inertia: 0.37794435907066304
# Minibatch step 426/213581: mean batch inertia: 0.32649432164317843, ewa inertia: 0.3778961807190979
# Minibatch step 427/213581: mean batch inertia: 0.3077974011084225, ewa inertia: 0.3778305394908845
# Minibatch step 428/213581: mean batch inertia: 0.2845127077686561, ewa inertia: 0.37774315570014694
# Minibatch step 429/213581: mean batch inertia: 0.29352335043271427, ewa inertia: 0.3776642913962553
# Minibatch step 430/213581: mean batch inertia: 0.3216403724123295, ewa inertia: 0.3776118300143046
# Minibatch step 431/213581: mean batch inertia: 0.3174511509474485, ewa inertia: 0.37755549492707435
# Minibatch step 432/213581: mean batch inertia: 0.3129786228896827, ewa inertia: 0.37749502447069466
# Minibatch step 433/213581: mean batch inertia: 0.3112739704971594, ewa inertia: 0.37743301438520455
# Minibatch step 434/213581: mean batch inertia: 0.3088728314225858, ewa inertia: 0.37736881391493676
# Minibatch step 435/213581: mean batch inertia: 0.3244074437949468, ewa inertia: 0.37731922033567833
# Minibatch step 436/213581: mean batch inertia: 0.2909009594812368, ewa inertia: 0.37723829737504966
# Minibatch step 437/213581: mean batch inertia: 0.33806661268835553, ewa inertia: 0.377201616601029
# Minibatch step 438/213581: mean batch inertia: 0.30687388018417433, ewa inertia: 0.3771357609752748
# Minibatch step 439/213581: mean batch inertia: 0.32550266928047433, ewa inertia: 0.3770874112097849
# Minibatch step 440/213581: mean batch inertia: 0.32459398563643016, ewa inertia: 0.3770382558186796
# Minibatch step 441/213581: mean batch inertia: 0.33189665450343503, ewa inertia: 0.37699598475247403
# Minibatch step 442/213581: mean batch inertia: 0.3008863673408613, ewa inertia: 0.3769247149130632
# Minibatch step 443/213581: mean batch inertia: 0.3039500798315859, ewa inertia: 0.3768563807037977
# Minibatch step 444/213581: mean batch inertia: 0.2900824154410474, ewa inertia: 0.37677512465785185
# Minibatch step 445/213581: mean batch inertia: 0.2990287063719595, ewa inertia: 0.3767023221010338
# Minibatch step 446/213581: mean batch inertia: 0.31517003856841125, ewa inertia: 0.37664470262907884
# Minibatch step 447/213581: mean batch inertia: 0.31760114920239724, ewa inertia: 0.3765894136299474
# Minibatch step 448/213581: mean batch inertia: 0.3318947254201772, ewa inertia: 0.37654756105783416
# Minibatch step 449/213581: mean batch inertia: 0.3101744614926673, ewa inertia: 0.3764854085952665
# Minibatch step 450/213581: mean batch inertia: 0.3067893203110084, ewa inertia: 0.3764201444514104
# Minibatch step 451/213581: mean batch inertia: 0.3110581432420315, ewa inertia: 0.37635893879188687
# Minibatch step 452/213581: mean batch inertia: 0.33007463187491765, ewa inertia: 0.3763155976842398
# Minibatch step 453/213581: mean batch inertia: 0.31402001739728713, ewa inertia: 0.37625726345324445
# Minibatch step 454/213581: mean batch inertia: 0.2901956741151068, ewa inertia: 0.376176674483543
# Minibatch step 455/213581: mean batch inertia: 0.3152510753494306, ewa inertia: 0.3761196231171853
# Minibatch step 456/213581: mean batch inertia: 0.3291774283877473, ewa inertia: 0.37607566595653014
# Minibatch step 457/213581: mean batch inertia: 0.298492082819592, ewa inertia: 0.3760030158802436
# Minibatch step 458/213581: mean batch inertia: 0.327421414715742, ewa inertia: 0.3759575235623071
# Minibatch step 459/213581: mean batch inertia: 0.3204425051079754, ewa inertia: 0.3759055387201191
# Minibatch step 460/213581: mean batch inertia: 0.3054182781525467, ewa inertia: 0.37583953371428663
# Minibatch step 461/213581: mean batch inertia: 0.3351612504538376, ewa inertia: 0.37580144214565075
# Minibatch step 462/213581: mean batch inertia: 0.2957612289142798, ewa inertia: 0.37572649165532623
# Minibatch step 463/213581: mean batch inertia: 0.29402182479870487, ewa inertia: 0.3756499825532702
# Minibatch step 464/213581: mean batch inertia: 0.3257019966151404, ewa inertia: 0.37560321073838304
# Minibatch step 465/213581: mean batch inertia: 0.32641774497384124, ewa inertia: 0.375557152955338
# Minibatch step 466/213581: mean batch inertia: 0.3240106554845528, ewa inertia: 0.3755088842775825
# Minibatch step 467/213581: mean batch inertia: 0.30627727150646716, ewa inertia: 0.3754440550734404
# Minibatch step 468/213581: mean batch inertia: 0.30076906405871845, ewa inertia: 0.3753741286331478
# Minibatch step 469/213581: mean batch inertia: 0.30328664499720714, ewa inertia: 0.37530662516174707
# Minibatch step 470/213581: mean batch inertia: 0.3110564732224758, ewa inertia: 0.3752464606494743
# Minibatch step 471/213581: mean batch inertia: 0.29570176007844645, ewa inertia: 0.3751719741623721
# Minibatch step 472/213581: mean batch inertia: 0.31898091666851397, ewa inertia: 0.3751193562701778
# Minibatch step 473/213581: mean batch inertia: 0.30212774845610363, ewa inertia: 0.37505100616746845
# Minibatch step 474/213581: mean batch inertia: 0.3009133843673004, ewa inertia: 0.374981582925312
# Minibatch step 475/213581: mean batch inertia: 0.3072652754250776, ewa inertia: 0.3749181726688271
# Minibatch step 476/213581: mean batch inertia: 0.3070374744787343, ewa inertia: 0.3748546084751859
# Minibatch step 477/213581: mean batch inertia: 0.30785887260398015, ewa inertia: 0.37479187296948846
# Minibatch step 478/213581: mean batch inertia: 0.3056838108205174, ewa inertia: 0.3747271594594373
# Minibatch step 479/213581: mean batch inertia: 0.3118374276037518, ewa inertia: 0.3746682688587172
# Minibatch step 480/213581: mean batch inertia: 0.32778695893632775, ewa inertia: 0.37462436871123034
# Minibatch step 481/213581: mean batch inertia: 0.3091807793015062, ewa inertia: 0.37456308665166516
# Minibatch step 482/213581: mean batch inertia: 0.3282588580188671, ewa inertia: 0.3745197268891156
# ...
# Minibatch step 2348/213581: mean batch inertia: 0.29529325045642324, ewa inertia: 0.320840648549611
# Minibatch step 2349/213581: mean batch inertia: 0.3157264044492507, ewa inertia: 0.32083585951810434
# Minibatch step 2350/213581: mean batch inertia: 0.314363384530254, ewa inertia: 0.32082979862503114
# Minibatch step 2351/213581: mean batch inertia: 0.3065537588016121, ewa inertia: 0.32081643039247076
# Minibatch step 2352/213581: mean batch inertia: 0.29143002899906323, ewa inertia: 0.3207889126597663
# Minibatch step 2353/213581: mean batch inertia: 0.3175011368669889, ewa inertia: 0.3207858339522292
# Minibatch step 2354/213581: mean batch inertia: 0.3102651824032367, ewa inertia: 0.32077598230440996
# Minibatch step 2355/213581: mean batch inertia: 0.3166471766978077, ewa inertia: 0.32077211604778494
# Minibatch step 2356/213581: mean batch inertia: 0.30530595573902275, ewa inertia: 0.3207576333739916
# Minibatch step 2357/213581: mean batch inertia: 0.3137909592074334, ewa inertia: 0.32075110970765397
# Minibatch step 2358/213581: mean batch inertia: 0.29299180666603586, ewa inertia: 0.3207251156068134
# Minibatch step 2359/213581: mean batch inertia: 0.3080279364029595, ewa inertia: 0.3207132258358015
# Minibatch step 2360/213581: mean batch inertia: 0.3134817013771462, ewa inertia: 0.3207064541608885
# Minibatch step 2361/213581: mean batch inertia: 0.3088071470685232, ewa inertia: 0.32069531152564196
# Minibatch step 2362/213581: mean batch inertia: 0.306839234124864, ewa inertia: 0.3206823365502735
# Minibatch step 2363/213581: mean batch inertia: 0.305298956902876, ewa inertia: 0.3206679313931547
# Minibatch step 2364/213581: mean batch inertia: 0.3179554114696645, ewa inertia: 0.32066539136121236
# Minibatch step 2365/213581: mean batch inertia: 0.31850342567894024, ewa inertia: 0.32066336687400265
# Minibatch step 2366/213581: mean batch inertia: 0.2951291659115232, ewa inertia: 0.32063945638195224
# Minibatch step 2367/213581: mean batch inertia: 0.3164739415250234, ewa inertia: 0.3206355557504024
# Minibatch step 2368/213581: mean batch inertia: 0.3292354199830545, ewa inertia: 0.32064360875294873
# Minibatch step 2369/213581: mean batch inertia: 0.32395386974918444, ewa inertia: 0.3206467085158648
# Minibatch step 2370/213581: mean batch inertia: 0.30084666836323315, ewa inertia: 0.32062816755179224
# Minibatch step 2371/213581: mean batch inertia: 0.32246911137890677, ewa inertia: 0.32062989143078924
# Minibatch step 2372/213581: mean batch inertia: 0.3124874992731254, ewa inertia: 0.3206222668098644
# Minibatch step 2373/213581: mean batch inertia: 0.2971607166649637, ewa inertia: 0.32060029716965305
# Minibatch step 2374/213581: mean batch inertia: 0.30221940265463637, ewa inertia: 0.32058308510835426
# Minibatch step 2375/213581: mean batch inertia: 0.3002387967229197, ewa inertia: 0.32056403450456106
# Minibatch step 2376/213581: mean batch inertia: 0.3076187261066306, ewa inertia: 0.3205519123827843
# Minibatch step 2377/213581: mean batch inertia: 0.30316681419074865, ewa inertia: 0.3205356327955465
# Minibatch step 2378/213581: mean batch inertia: 0.2733801136825675, ewa inertia: 0.3204914758757141
# Minibatch step 2379/213581: mean batch inertia: 0.3107142910941606, ewa inertia: 0.32048232041792873
# Minibatch step 2380/213581: mean batch inertia: 0.28297753950007143, ewa inertia: 0.3204472005499796
# Minibatch step 2381/213581: mean batch inertia: 0.2893056970960428, ewa inertia: 0.32041803932140356
# Minibatch step 2382/213581: mean batch inertia: 0.2830092895356022, ewa inertia: 0.32038300937800784
# Minibatch step 2383/213581: mean batch inertia: 0.3072847315494184, ewa inertia: 0.32037074401406107
# Minibatch step 2384/213581: mean batch inertia: 0.31167139940381133, ewa inertia: 0.3203625978570518
# Minibatch step 2385/213581: mean batch inertia: 0.3011949504703164, ewa inertia: 0.3203446490721597
# Minibatch step 2386/213581: mean batch inertia: 0.32657659808963196, ewa inertia: 0.320350484734206
# Minibatch step 2387/213581: mean batch inertia: 0.3122539673337551, ewa inertia: 0.3203429030708822
# Minibatch step 2388/213581: mean batch inertia: 0.30649325577224074, ewa inertia: 0.32032993411672844
# Minibatch step 2389/213581: mean batch inertia: 0.2985464681541575, ewa inertia: 0.3203095358520444
# Minibatch step 2390/213581: mean batch inertia: 0.2760530247745126, ewa inertia: 0.32026809359356706
# Minibatch step 2391/213581: mean batch inertia: 0.30886643002096864, ewa inertia: 0.3202574169569018
# Minibatch step 2392/213581: mean batch inertia: 0.29648199632909183, ewa inertia: 0.32023515340509723
# Minibatch step 2393/213581: mean batch inertia: 0.31140421008334757, ewa inertia: 0.3202268840176822
# Minibatch step 2394/213581: mean batch inertia: 0.28669823827045515, ewa inertia: 0.32019548744416976
# Minibatch step 2395/213581: mean batch inertia: 0.32332882366854704, ewa inertia: 0.3201984215328845
# Minibatch step 2396/213581: mean batch inertia: 0.32116569783413934, ewa inertia: 0.3201993273004997
# Minibatch step 2397/213581: mean batch inertia: 0.3207469163300564, ewa inertia: 0.3201998400685772
# Minibatch step 2398/213581: mean batch inertia: 0.3027904311539922, ewa inertia: 0.3201835377165253
# Minibatch step 2399/213581: mean batch inertia: 0.29134289181023487, ewa inertia: 0.32015653103495006
# Minibatch step 2400/213581: mean batch inertia: 0.31313651937566284, ewa inertia: 0.32014995742282804
# Minibatch step 2401/213581: mean batch inertia: 0.29527653962194944, ewa inertia: 0.32012666569502074
# Minibatch step 2402/213581: mean batch inertia: 0.29571120392950495, ewa inertia: 0.3201038028020205
# Minibatch step 2403/213581: mean batch inertia: 0.3199662031184469, ewa inertia: 0.32010367395224193
# Minibatch step 2404/213581: mean batch inertia: 0.3101089864508058, ewa inertia: 0.32009431482264156
# Minibatch step 2405/213581: mean batch inertia: 0.2873408425069043, ewa inertia: 0.32006364412961386
# Minibatch step 2406/213581: mean batch inertia: 0.3210462197367615, ewa inertia: 0.32006456422365864
# Minibatch step 2407/213581: mean batch inertia: 0.3098240128582307, ewa inertia: 0.3200549748645722
# Minibatch step 2408/213581: mean batch inertia: 0.31169423966034193, ewa inertia: 0.32004714578494164
# Minibatch step 2409/213581: mean batch inertia: 0.29753629457925357, ewa inertia: 0.32002606638913084
# Minibatch step 2410/213581: mean batch inertia: 0.2975718373556522, ewa inertia: 0.3200050400149125
# Minibatch step 2411/213581: mean batch inertia: 0.32033756863400564, ewa inertia: 0.3200053513981789
# Minibatch step 2412/213581: mean batch inertia: 0.33615238739142156, ewa inertia: 0.3200204716510633
# Minibatch step 2413/213581: mean batch inertia: 0.3023586401715818, ewa inertia: 0.32000393292788937
# Minibatch step 2414/213581: mean batch inertia: 0.3049742859400682, ewa inertia: 0.31998985900972166
# Minibatch step 2415/213581: mean batch inertia: 0.3333179157819234, ewa inertia: 0.3200023395410673
# Minibatch step 2416/213581: mean batch inertia: 0.31107694090063537, ewa inertia: 0.3199939817047069
# Minibatch step 2417/213581: mean batch inertia: 0.2876851384802951, ewa inertia: 0.31996372736699685
# Minibatch step 2418/213581: mean batch inertia: 0.31486158013984783, ewa inertia: 0.31995894966312843
# Minibatch step 2419/213581: mean batch inertia: 0.29825045703916525, ewa inertia: 0.31993862160426045
# Minibatch step 2420/213581: mean batch inertia: 0.32798120517238366, ewa inertia: 0.31994615276338123
# Minibatch step 2421/213581: mean batch inertia: 0.32066272143836416, ewa inertia: 0.31994682376576083
# Minibatch step 2422/213581: mean batch inertia: 0.2801479169585329, ewa inertia: 0.3199095556544059
# Minibatch step 2423/213581: mean batch inertia: 0.3075310898122222, ewa inertia: 0.31989796432990936
# Minibatch step 2424/213581: mean batch inertia: 0.28608935610346226, ewa inertia: 0.3198663055966119
# Minibatch step 2425/213581: mean batch inertia: 0.2925642308374178, ewa inertia: 0.3198407396491029
# Minibatch step 2426/213581: mean batch inertia: 0.31055713822859826, ewa inertia: 0.3198320463879239
# Minibatch step 2427/213581: mean batch inertia: 0.3010342332001701, ewa inertia: 0.3198144439196324
# Minibatch step 2428/213581: mean batch inertia: 0.30368174428204164, ewa inertia: 0.31979933709146086
# Minibatch step 2429/213581: mean batch inertia: 0.2952472512944922, ewa inertia: 0.31977634626229284
# Minibatch step 2430/213581: mean batch inertia: 0.32737397732491175, ewa inertia: 0.3197834607632475
# Minibatch step 2431/213581: mean batch inertia: 0.32220489741346103, ewa inertia: 0.3197857282217773
# Minibatch step 2432/213581: mean batch inertia: 0.30123581897377677, ewa inertia: 0.31976835789332014
# Minibatch step 2433/213581: mean batch inertia: 0.31458708585497375, ewa inertia: 0.31976350609615345
# Minibatch step 2434/213581: mean batch inertia: 0.28809093210232134, ewa inertia: 0.3197338475675859
# Minibatch step 2435/213581: mean batch inertia: 0.3050191412063386, ewa inertia: 0.31972006856310514
# Minibatch step 2436/213581: mean batch inertia: 0.29146622086609325, ewa inertia: 0.3196936113654922
# Minibatch step 2437/213581: mean batch inertia: 0.317876703959531, ewa inertia: 0.31969190999445063
# Minibatch step 2438/213581: mean batch inertia: 0.3135135809651155, ewa inertia: 0.3196861245427203
# Minibatch step 2439/213581: mean batch inertia: 0.31839752707858904, ewa inertia: 0.31968491788661746
# Minibatch step 2440/213581: mean batch inertia: 0.31025380904501204, ewa inertia: 0.3196760864979511
# Minibatch step 2441/213581: mean batch inertia: 0.32394699762396023, ewa inertia: 0.3196800858236663
# Minibatch step 2442/213581: mean batch inertia: 0.317760373335379, ewa inertia: 0.3196782881848736
# Minibatch step 2443/213581: mean batch inertia: 0.2866865720056462, ewa inertia: 0.31964739439780765
# Minibatch step 2444/213581: mean batch inertia: 0.2985652943437618, ewa inertia: 0.3196276528994741
# Minibatch step 2445/213581: mean batch inertia: 0.2894492400285864, ewa inertia: 0.31959939351896305
# Minibatch step 2446/213581: mean batch inertia: 0.31186558547128873, ewa inertia: 0.3195921515004595
# Minibatch step 2447/213581: mean batch inertia: 0.31916558691154817, ewa inertia: 0.3195917520609302
# Minibatch step 2448/213581: mean batch inertia: 0.3092469200059136, ewa inertia: 0.31958206505231856
# Minibatch step 2449/213581: mean batch inertia: 0.31503260930831173, ewa inertia: 0.3195778048945184
# Minibatch step 2450/213581: mean batch inertia: 0.29638671204951916, ewa inertia: 0.31955608851334305
# Minibatch step 2451/213581: mean batch inertia: 0.2986188706701329, ewa inertia: 0.3195364826842226
# Minibatch step 2452/213581: mean batch inertia: 0.305204206807689, ewa inertia: 0.31952306179163564
# Minibatch step 2453/213581: mean batch inertia: 0.3100176238570141, ewa inertia: 0.3195141608004315
# Minibatch step 2454/213581: mean batch inertia: 0.32220581804275167, ewa inertia: 0.31951668129634164
# Minibatch step 2455/213581: mean batch inertia: 0.3096939867247222, ewa inertia: 0.3195074832227143
# Minibatch step 2456/213581: mean batch inertia: 0.30929505770140536, ewa inertia: 0.31949792020096157
# Minibatch step 2457/213581: mean batch inertia: 0.2886485942482781, ewa inertia: 0.3194690325704445
# Minibatch step 2458/213581: mean batch inertia: 0.2992322463492809, ewa inertia: 0.31945008263279895
# Minibatch step 2459/213581: mean batch inertia: 0.29695972165932144, ewa inertia: 0.31942902242425525
# Minibatch step 2460/213581: mean batch inertia: 0.2896869293624663, ewa inertia: 0.3194011716181634
# Minibatch step 2461/213581: mean batch inertia: 0.3227100426187847, ewa inertia: 0.3194042700794731
# Minibatch step 2462/213581: mean batch inertia: 0.3076171295605288, ewa inertia: 0.3193932324781755
# Minibatch step 2463/213581: mean batch inertia: 0.2931094060202766, ewa inertia: 0.31936862002899413
# Minibatch step 2464/213581: mean batch inertia: 0.30909498241330646, ewa inertia: 0.3193589996875979
# Minibatch step 2465/213581: mean batch inertia: 0.295272049662531, ewa inertia: 0.3193364444164171
# Minibatch step 2466/213581: mean batch inertia: 0.31730287050882244, ewa inertia: 0.31933454015660406
# Minibatch step 2467/213581: mean batch inertia: 0.29565465151979836, ewa inertia: 0.31931236606195207
# Minibatch step 2468/213581: mean batch inertia: 0.3067854342587966, ewa inertia: 0.3193006357123815
# Minibatch step 2469/213581: mean batch inertia: 0.31365696494277845, ewa inertia: 0.31929535092022093
# Minibatch step 2470/213581: mean batch inertia: 0.2932136067455846, ewa inertia: 0.31927092770299687
# Minibatch step 2471/213581: mean batch inertia: 0.2867864721023062, ewa inertia: 0.31924050892002637
# Minibatch step 2472/213581: mean batch inertia: 0.30953917981874873, ewa inertia: 0.31923142449429104
# Minibatch step 2473/213581: mean batch inertia: 0.29567982946590543, ewa inertia: 0.3192093705351118
# Minibatch step 2474/213581: mean batch inertia: 0.2877171837051288, ewa inertia: 0.31917988092296545
# Minibatch step 2475/213581: mean batch inertia: 0.31746917709692973, ewa inertia: 0.31917827900206364
# Minibatch step 2476/213581: mean batch inertia: 0.32077709242196106, ewa inertia: 0.3191797761476224
# Minibatch step 2477/213581: mean batch inertia: 0.3159449323571806, ewa inertia: 0.3191767470061643
# Minibatch step 2478/213581: mean batch inertia: 0.30260483504683605, ewa inertia: 0.3191612288949946
# Minibatch step 2479/213581: mean batch inertia: 0.2981212894547295, ewa inertia: 0.3191415268762995
# Minibatch step 2480/213581: mean batch inertia: 0.3175756910777484, ewa inertia: 0.31914006061132927
# Minibatch step 2481/213581: mean batch inertia: 0.31029710271011657, ewa inertia: 0.3191317799733367
# Minibatch step 2482/213581: mean batch inertia: 0.2862129268829615, ewa inertia: 0.319100954416027
# Minibatch step 2483/213581: mean batch inertia: 0.3336789656550801, ewa inertia: 0.31911460541776987
# Minibatch step 2484/213581: mean batch inertia: 0.30367772306740043, ewa inertia: 0.3191001501601621
# Minibatch step 2485/213581: mean batch inertia: 0.3006107101435005, ewa inertia: 0.31908283645572366
# Minibatch step 2486/213581: mean batch inertia: 0.30230662907071865, ewa inertia: 0.319067127040187
# Minibatch step 2487/213581: mean batch inertia: 0.317145905649707, ewa inertia: 0.31906532798844256
# Minibatch step 2488/213581: mean batch inertia: 0.3123065324871856, ewa inertia: 0.31905899898185486
# Minibatch step 2489/213581: mean batch inertia: 0.3057584548171886, ewa inertia: 0.3190465442136018
# Minibatch step 2490/213581: mean batch inertia: 0.3424357940527444, ewa inertia: 0.3190684461510529
# Minibatch step 2491/213581: mean batch inertia: 0.29027708603936336, ewa inertia: 0.3190414856212097
# Minibatch step 2492/213581: mean batch inertia: 0.3295876223932686, ewa inertia: 0.31905136113365756
# Minibatch step 2493/213581: mean batch inertia: 0.31487059612720447, ewa inertia: 0.3190474462217087
# Minibatch step 2494/213581: mean batch inertia: 0.3237838941260048, ewa inertia: 0.3190518814809177
# Minibatch step 2495/213581: mean batch inertia: 0.3049523589390681, ewa inertia: 0.31903867854098045
# Minibatch step 2496/213581: mean batch inertia: 0.3229849241680701, ewa inertia: 0.3190423738465369
# Minibatch step 2497/213581: mean batch inertia: 0.32916417737872766, ewa inertia: 0.319051852008914
# Minibatch step 2498/213581: mean batch inertia: 0.33638735428478883, ewa inertia: 0.31906808515401874
# Minibatch step 2499/213581: mean batch inertia: 0.30199674977515256, ewa inertia: 0.3190520993775511
# Minibatch step 2500/213581: mean batch inertia: 0.33564756900665804, ewa inertia: 0.31906763954836836
# Minibatch step 2501/213581: mean batch inertia: 0.32272841126830715, ewa inertia: 0.3190710675331812
# Minibatch step 2502/213581: mean batch inertia: 0.31905734103200445, ewa inertia: 0.3190710546795424
# Minibatch step 2503/213581: mean batch inertia: 0.30592983792703493, ewa inertia: 0.3190587491071395
# Minibatch step 2504/213581: mean batch inertia: 0.3161463015808233, ewa inertia: 0.319056021860905
# Minibatch step 2505/213581: mean batch inertia: 0.3083817922253013, ewa inertia: 0.31904602640096397
# Converged (lack of improvement in inertia) at step 2505/213581

# %%
bp = scaler.inverse_transform(bp)

# %%
clustered_data = pd.DataFrame(bp, columns=['BPM', 'Key'])
clustered_data['Cluster'] = mbkmeans_clusters

# Generate summary statistics for each cluster
summary = clustered_data.groupby('Cluster').agg(['mean', 'median', 'std'])
summary
# Out:
#                 BPM                          Key
#                mean median        std       mean median       std
# Cluster
# 0        124.923770  125.0   5.367779   3.650383    3.0  2.125869
# 1         93.535433   93.0   7.960917  18.256017   19.0  3.192156
# 2         61.170251   70.0  25.138773  14.242136   15.0  5.043077
# 3        124.895842  125.0   4.659857  19.707023   19.0  2.242730
# 4        147.527680  145.0  10.862713  18.277560   19.0  2.929306
# 5         90.578655   90.0   9.198681   5.835435    6.0  3.458753
# 6        125.059638  125.0   5.433876  11.653888   12.0  2.307267
# 7        149.050371  146.0  11.458105   6.811215    7.0  3.293036

# %%
from sklearn.metrics import classification_report, confusion_matrix

X = clustered_data[['BPM', 'Key']]
y = clustered_data['Cluster']

# Step 1: Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2170020
#            1       1.00      1.00      1.00    715316
#            2       1.00      1.00      1.00    223964
#            3       1.00      1.00      1.00   2461563
#            4       1.00      1.00      1.00    524911
#            5       1.00      1.00      1.00    782963
#            6       1.00      1.00      1.00   2256769
#            7       1.00      1.00      1.00    475664
#
#     accuracy                           1.00   9611170
#    macro avg       1.00      1.00      1.00   9611170
# weighted avg       1.00      1.00      1.00   9611170

# %%
# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', cbar=False, 
            xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))

# Add labels and title
plt.xlabel('Predicted Cluster')
plt.ylabel('True Cluster')
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %%
feature_importances = clf.feature_importances_
features = ['BPM', 'Key']

# Plot the feature importances
plt.barh(features, feature_importances)
plt.title('Feature Importance in Predicting Clusters')
plt.show()

# %%
bp_artist = pd.read_csv('data/bp_artist.csv')
bp_artist_track = pd.read_csv('data/bp_artist_track.csv')
track_id = pd.read_csv('data/bp_track.csv', usecols=['track_id', 'title', 'key_id'])

# %%
bp_track.head(2)
# Out:
#    bpm  key_id broad_genre
# 0  130      20      Trance
# 1  124       4      Trance

# %%
track_id = track_id.dropna(subset=['key_id'])

# %%
bp_track['Cluster'] = mbkmeans_clusters
bp_track['track_id'] = track_id['track_id']
bp_track['title'] = track_id['title']

# %%
bp_track.head(2)
# Out:
#    bpm  key_id broad_genre  Cluster    track_id           title
# 0  130      20      Trance        3  17775434.0  Navigator 3000
# 1  124       4      Trance        0  17610335.0         Nehorah

# %%
bp_artist.head(2)
# Out:
#    artist_id artist_name                           artist_url  \
# 0      31526     Tromesa    beatport.com/artist/tromesa/31526
# 1     943790  Magik (UK)  beatport.com/artist/magik-uk/943790
#
#             updated_on
# 0  2023-09-14 16:19:56
# 1  2023-09-14 16:19:56

# %%
bp_artist_track.head(2)
# Out:
#    artist_id  track_id           updated_on is_remixer
# 0      31526  17767172  2023-09-14 16:19:56          f
# 1     943790  17767172  2023-09-14 16:19:56          f

# %%
# Step 1: Merge bp_track with bp_artist_track on 'track_id'
track_artist_merge = pd.merge(bp_track, bp_artist_track, on='track_id', how='left')

# Step 2: Merge the result with bp_artist to get artist names
track_artist_merge = pd.merge(track_artist_merge, bp_artist[['artist_id', 'artist_name']], on='artist_id', how='left')

# Step 3: Convert artist_name to string and handle NaN values
track_artist_merge['artist_name'] = track_artist_merge['artist_name'].fillna('').astype(str)

# Step 4: Group by track_id and aggregate the artist names using 'agg()'
track_artist_agg = track_artist_merge.groupby('track_id').agg({
    'title': 'first',  # Keep the title (same for all rows)
    'artist_name': lambda x: ', '.join(x)  # Concatenate artist names
}).reset_index()

# %%
# Step 1: Merge bp_track with bp_artist_track on 'track_id'
track_artist_merge = pd.merge(bp_track, bp_artist_track, on='track_id', how='left')

# Step 2: Merge the result with bp_artist to get artist names
track_artist_merge = pd.merge(track_artist_merge, bp_artist[['artist_id', 'artist_name']], on='artist_id', how='left')

# Step 3: Convert artist_name to string and handle NaN values
track_artist_merge['artist_name'] = track_artist_merge['artist_name'].fillna('').astype(str)

# Step 4: Group by track_id and aggregate the artist names using 'agg()'
track_artist_agg = track_artist_merge.groupby('track_id').agg({
    'title': 'first',  # Keep the title (same for all rows)
    'artist_name': lambda x: ', '.join(x)  # Concatenate artist names
}).reset_index()

# Step 5: Merge back with bp_track to preserve bpm, key_id, cluster, and track_id
bp_track_updated = pd.merge(bp_track, track_artist_agg[['track_id', 'title', 'artist_name']], on='track_id', how='left')

# Step 6: Use the correct 'title_x' column
bp_track_updated['song'] = bp_track_updated['title_x'] + ' by ' + bp_track_updated['artist_name']

# Step 7: Keep the necessary columns: bpm, key_id, cluster, track_id, song
bp_track_final = bp_track_updated[['bpm', 'key_id', 'Cluster', 'track_id', 'song']]

# Display the final DataFrame
bp_track_final.head()
# Out:
#    bpm  key_id  Cluster    track_id                                song
# 0  130      20        3  17775434.0       Navigator 3000 by Abdul Raeva
# 1  124       4        0  17610335.0                    Nehorah by Ormus
# 2  124       6        0  17610338.0                      Akawi by Ormus
# 3   93      10        5  17658499.0    Interplanetary Species by CJ Art
# 4  125       2        0  17658498.0  Echoing Planetary Motion by CJ Art

# %%
bp_track = bp_track_final.dropna()

# %%
bp_track['track_id'] = bp_track['track_id'].astype(int)
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\3835127561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bp_track['track_id'] = bp_track['track_id'].astype(int)

# %%
from scipy.spatial.distance import euclidean

def find_similar_song(input_song, song_data, n_recommendations=1):
    # Extract the features of the input song
    input_features = song_data[song_data['track_id'] == input_song][['bpm', 'key_id']].values[0]
    
    # Compute the Euclidean distance to all other songs
    song_data['distance'] = song_data.apply(lambda row: euclidean(input_features, row[['bpm', 'key_id']].values), axis=1)
    
    # Sort by the smallest distance and return n recommendations
    recommendations = song_data.sort_values('distance').head(n_recommendations)
    
    return recommendations[['track_id', 'song', 'bpm', 'key_id', 'Cluster']]

# %%
def recommend_songs(input_song, song_data, n_recommendations=5):
    # Find the cluster of the input song
    input_cluster = song_data[song_data['track_id'] == input_song]['Cluster'].values[0]
    
    # Find songs from the same cluster
    same_cluster_songs = song_data[song_data['Cluster'] == input_cluster]
    
    # Sort by distance in terms of features (BPM and Key)
    recommendations = find_similar_song(input_song, same_cluster_songs, n_recommendations=n_recommendations)
    
    return recommendations

# %%
input_song = 4993057
recommended_songs = recommend_songs(input_song, bp_track, n_recommendations=5)

print("Recommended Songs:")
print(recommended_songs)
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\3242121264.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_data['distance'] = song_data.apply(lambda row: euclidean(input_features, row[['bpm', 'key_id']].values), axis=1)
# Recommended Songs:
#            track_id                                     song  bpm  key_id  \
# 1879828  16732451.0                     Promo by Electro SIN  110      11
# 852543   11786481.0        Muzzdabear by Oxyenen, Techno Red  110      11
# 2267851  16888590.0  Bing Bang Bang Bang by Dragon5, Ray(CN)  110      11
# 5844771  15710996.0                   Disco Marsh by Q-Green  110      11
# 852396   13804042.0                     Copahabano by Stazam  110      11
#
#          Cluster
# 1879828        6
# 852543         6
# 2267851        6
# 5844771        6
# 852396         6

# %%
def find_similar_song(input_song, song_data, n_recommendations=1):
    # Extract the features of the input song
    input_features = song_data[song_data['track_id'] == input_song][['bpm', 'key_id']].values[0]

    # Compute the Euclidean distance to all other songs
    song_data['distance'] = song_data.apply(
        lambda row: euclidean(input_features, row[['bpm', 'key_id']].values), axis=1
    )

    # Sort by the smallest distance and return the n recommendations
    recommendations = song_data.sort_values('distance').head(n_recommendations)

    return recommendations[['track_id', 'song', 'bpm', 'key_id']]

# %%
def recommend_songs(input_song, song_data, n_recommendations=5):
    # Find the cluster of the input song
    input_cluster = song_data[song_data['track_id'] == input_song]['Cluster'].values[0]

    # Find songs from the same cluster
    same_cluster_songs = song_data[song_data['Cluster'] == input_cluster]

    # Sort by distance in terms of features (BPM and Key)
    recommendations = find_similar_song(input_song, same_cluster_songs, n_recommendations=n_recommendations)

    return recommendations

# %%
# Input song and recommendations
input_song = 4993057
recommended_songs = recommend_songs(input_song, bp_track, n_recommendations=5)

# Output the song name, bpm, and key_id of the input song and the recommendations
input_song_info = bp_track[bp_track['track_id'] == input_song][['song', 'bpm', 'key_id']].values[0]
print(f"Input Song: {input_song_info[0]} (BPM: {input_song_info[1]}, Key: {input_song_info[2]})\n")

print("Recommended Songs:")
for index, row in recommended_songs.iterrows():
    print(f" - {row['song']} (BPM: {row['bpm']}, Key: {row['key_id']})")
# Out:
# C:\Users\Shank\AppData\Local\Temp\ipykernel_17968\3081161967.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_data['distance'] = song_data.apply(
# Input Song: Booyah feat. We Are Loud feat. Sonny Wilson by Showtek, Sonny Wilson, We Are Loud (BPM: 110, Key: 11)
#
# Recommended Songs:
#  - Promo by Electro SIN (BPM: 110, Key: 11)
#  - Muzzdabear by Oxyenen, Techno Red (BPM: 110, Key: 11)
#  - Bing Bang Bang Bang by Dragon5, Ray(CN) (BPM: 110, Key: 11)
#  - Disco Marsh by Q-Green (BPM: 110, Key: 11)
#  - Copahabano by Stazam (BPM: 110, Key: 11)
